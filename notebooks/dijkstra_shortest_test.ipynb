# %%
from pathlib import Path
import sys

import pandas as pd

project_root = Path.cwd()
if not (project_root / "src").exists():
    project_root = project_root.parent

if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

from src.dijkstra_shortest_in_day import dijkstra
from src.utils import print_path

# %%
# Żagań --> Wrocław Główny
result = dijkstra(1413422, 1413380, None, pd.Timestamp("2026-03-10"))
print_path(result)
# Out:
# Optimal path: 05:51:00 - 07:48:00
#
# Line:		D14
# Stops:		Żagań ---> Małomice
# Dates:		2026-03-10 - 2026-03-10
# Times:		05:51:00 - 05:59:00
#
# Line:		D14
# Stops:		Małomice ---> Leszno Górne
# Dates:		2026-03-10 - 2026-03-10
# Times:		06:00:00 - 06:11:00
#
# Line:		D14
# Stops:		Leszno Górne ---> Wierzbowa Śląska
# Dates:		2026-03-10 - 2026-03-10
# Times:		06:11:00 - 06:21:00
#
# Line:		D14
# Stops:		Wierzbowa Śląska ---> Modła
# Dates:		2026-03-10 - 2026-03-10
# Times:		06:21:00 - 06:25:00
#
# Line:		D14
# Stops:		Modła ---> Rokitki
# Dates:		2026-03-10 - 2026-03-10
# Times:		06:26:00 - 06:32:00
#
# Line:		D14
# Stops:		Rokitki ---> Miłkowice
# Dates:		2026-03-10 - 2026-03-10
# Times:		06:33:00 - 06:43:00
#
# Line:		D14
# Stops:		Miłkowice ---> Jezierzany
# Dates:		2026-03-10 - 2026-03-10
# Times:		06:43:00 - 06:47:00
#
# Line:		D14
# Stops:		Jezierzany ---> Legnica
# Dates:		2026-03-10 - 2026-03-10
# Times:		06:47:00 - 06:53:00
#
# Line:		D14
# ...

# %%
# Żary --> Głogów
# Przez Zieloną górę szybciej, ale to Polregio a nie KD...
path = dijkstra(1413424, 1413136, None, pd.Timestamp("2026-07-07"))
print_path(path)
# Out:
# Optimal path: 07:42:00 - 10:56:00
#
# Line:		D14
# Stops:		Żary ---> Żagań
# Dates:		2026-07-07 - 2026-07-07
# Times:		07:42:00 - 07:53:00
#
# Line:		D14
# Stops:		Żagań ---> Małomice
# Dates:		2026-07-07 - 2026-07-07
# Times:		07:54:00 - 08:03:00
#
# Line:		D14
# Stops:		Małomice ---> Leszno Górne
# Dates:		2026-07-07 - 2026-07-07
# Times:		08:03:00 - 08:15:00
#
# Line:		D14
# Stops:		Leszno Górne ---> Wierzbowa Śląska
# Dates:		2026-07-07 - 2026-07-07
# Times:		08:15:00 - 08:26:00
#
# Line:		D14
# Stops:		Wierzbowa Śląska ---> Modła
# Dates:		2026-07-07 - 2026-07-07
# Times:		08:26:00 - 08:30:00
#
# Line:		D14
# Stops:		Modła ---> Rokitki
# Dates:		2026-07-07 - 2026-07-07
# Times:		08:31:00 - 08:37:00
#
# Line:		D14
# Stops:		Rokitki ---> Miłkowice
# Dates:		2026-07-07 - 2026-07-07
# Times:		08:38:00 - 08:50:00
#
# Line:		D14
# Stops:		Miłkowice ---> Jezierzany
# Dates:		2026-07-07 - 2026-07-07
# Times:		08:51:00 - 08:55:00
#
# Line:		D14
# Stops:		Jezierzany ---> Legnica
# ...

# %%
# Żary --> Brzeg Dolny
path = dijkstra(1413424, 1413092, None, pd.Timestamp("2026-07-07"))
print_path(path)
# Out:
# Optimal path: 07:42:00 - 10:20:00
#
# Line:		D14
# Stops:		Żary ---> Żagań
# Dates:		2026-07-07 - 2026-07-07
# Times:		07:42:00 - 07:53:00
#
# Line:		D14
# Stops:		Żagań ---> Małomice
# Dates:		2026-07-07 - 2026-07-07
# Times:		07:54:00 - 08:03:00
#
# Line:		D14
# Stops:		Małomice ---> Leszno Górne
# Dates:		2026-07-07 - 2026-07-07
# Times:		08:03:00 - 08:15:00
#
# Line:		D14
# Stops:		Leszno Górne ---> Wierzbowa Śląska
# Dates:		2026-07-07 - 2026-07-07
# Times:		08:15:00 - 08:26:00
#
# Line:		D14
# Stops:		Wierzbowa Śląska ---> Modła
# Dates:		2026-07-07 - 2026-07-07
# Times:		08:26:00 - 08:30:00
#
# Line:		D14
# Stops:		Modła ---> Rokitki
# Dates:		2026-07-07 - 2026-07-07
# Times:		08:31:00 - 08:37:00
#
# Line:		D14
# Stops:		Rokitki ---> Miłkowice
# Dates:		2026-07-07 - 2026-07-07
# Times:		08:38:00 - 08:50:00
#
# Line:		D14
# Stops:		Miłkowice ---> Jezierzany
# Dates:		2026-07-07 - 2026-07-07
# Times:		08:51:00 - 08:55:00
#
# Line:		D14
# Stops:		Jezierzany ---> Legnica
# ...

# %%
# Zgorzelec --> Strzelin
path = dijkstra(1413417, 1413326, None, pd.Timestamp("2026-07-07"))
print_path(path)
# Out:
# Optimal path: 04:36:00 - 07:38:00
#
# Line:		D10
# Stops:		Zgorzelec ---> Zgorzelec Miasto
# Dates:		2026-07-07 - 2026-07-07
# Times:		04:36:00 - 04:38:00
#
# Line:		D10
# Stops:		Zgorzelec Miasto ---> Jędrzychowice
# Dates:		2026-07-07 - 2026-07-07
# Times:		04:39:00 - 04:41:00
#
# Line:		D10
# Stops:		Jędrzychowice ---> Pieńsk
# Dates:		2026-07-07 - 2026-07-07
# Times:		04:41:00 - 04:46:00
#
# Line:		D10
# Stops:		Pieńsk ---> Węgliniec
# Dates:		2026-07-07 - 2026-07-07
# Times:		04:47:00 - 04:55:00
#
# Line:		D10
# Stops:		Węgliniec ---> Zagajnik
# Dates:		2026-07-07 - 2026-07-07
# Times:		04:56:00 - 05:00:00
#
# Line:		D10
# Stops:		Zagajnik ---> Zebrzydowa
# Dates:		2026-07-07 - 2026-07-07
# Times:		05:00:00 - 05:05:00
#
# Line:		D10
# Stops:		Zebrzydowa ---> Bolesławiec
# Dates:		2026-07-07 - 2026-07-07
# Times:		05:05:00 - 05:13:00
#
# Line:		D10
# Stops:		Bolesławiec ---> Tomaszów Bolesławiecki
# Dates:		2026-07-07 - 2026-07-07
# Times:		05:14:00 - 05:19:00
#
# Line:		D10
# ...

# %%
# Rawicz --> Wałbrzych Główny
path = dijkstra(1413291, 1413365, None, pd.Timestamp("2026-07-07"))
print_path(path)
# Out:
# Optimal path: 14:17:00 - 16:32:00
#
# Line:		D30
# Stops:		Rawicz ---> Żmigród
# Dates:		2026-07-07 - 2026-07-07
# Times:		14:17:00 - 14:24:00
#
# Line:		D30
# Stops:		Żmigród ---> Oborniki Śląskie
# Dates:		2026-07-07 - 2026-07-07
# Times:		14:25:00 - 14:35:00
#
# Line:		D30
# Stops:		Oborniki Śląskie ---> Wrocław Mikołajów
# Dates:		2026-07-07 - 2026-07-07
# Times:		14:36:00 - 14:46:00
#
# Line:		D30
# Stops:		Wrocław Mikołajów ---> Wrocław Główny
# Dates:		2026-07-07 - 2026-07-07
# Times:		14:47:00 - 14:52:00
#
# Line:		D60
# Stops:		Wrocław Główny ---> Wrocław Grabiszyn
# Dates:		2026-07-07 - 2026-07-07
# Times:		15:10:00 - 15:15:00
#
# Line:		D60
# Stops:		Wrocław Grabiszyn ---> Wrocław Zachodni
# Dates:		2026-07-07 - 2026-07-07
# Times:		15:16:00 - 15:18:00
#
# Line:		D60
# Stops:		Wrocław Zachodni ---> Mokronos Górny
# Dates:		2026-07-07 - 2026-07-07
# Times:		15:18:00 - 15:21:00
#
# Line:		D60
# Stops:		Mokronos Górny ---> Smolec
# Dates:		2026-07-07 - 2026-07-07
# ...
