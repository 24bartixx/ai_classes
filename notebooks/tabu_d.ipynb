# %%
from pathlib import Path
import sys
import random

import pandas as pd

project_root = Path.cwd()
if not (project_root / "src").exists():
    project_root = project_root.parent

if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

from src.tabu_a import *
from src.graph import *
from src.utils import print_paths

# %%
test_time = pd.Timestamp("2026-10-09 11:00:00")
# graph = Graph(test_time, with_locations=True)
# restult = evaluate_solution_arr_time([1413424, 1413136, 1413137, 1413138, 1413139, 1413140, 1413141, 1413142, 1413144, 1413424, 1413136, 1413137, 1413138, 1413139, 1413140, 1413141, 1413142, 1413144, 1413424, 1413136, 1413137, 1413138, 1413139, 1413140, 1413141, 1413142, 1413144, 1413424, 1413136, 1413137, 1413138, 1413139, 1413140, 1413141, 1413142, 1413144, 1413424, 1413136, 1413137, 1413138, 1413139, 1413140, 1413141, 1413142, 1413144, 1413424, 1413136], graph, test_time, should_log=True)

# print(str(restult))

# %%
test_time = pd.Timestamp("2026-12-11 11:00:00")
# graph = Graph(test_time, with_locations=True)
# restult2 = evaluate_solution_arr_time([1413424, 1413136, 1413137, 1413138, 1413139, 1413140, 1413141, 1413142, 1413144, 1413424, 1413136, 1413137, 1413138, 1413139, 1413140, 1413141, 1413142, 1413144, 1413424, 1413136, 1413137, 1413138, 1413139, 1413140, 1413141, 1413142], graph, test_time, should_log=True)

# print(str(restult2))

# %%
test_time = pd.Timestamp("2026-07-03 11:00:00")
result = tabu_a(
    1413137, 
    [1413139, 1413137, 1413136, 1413138 , 1413424], 
    't', 
    pd.Timestamp("2026-12-11 11:00:00"),
    sample_neighbors=True
)

print_paths(result)
# Out:
# Fastest arrival: 2026-12-12 06:21:00
#
# Best city order:
# 	1. 1413137
# 	2. 1413139
# 	3. 1413424
# 	4. 1413136
# 	5. 1413138
# 	6. 1413137
# Execution time:		0.242981 seconds
# Minimized value:	2026-12-12 06:21:00 seconds

# %%
result = tabu_a(
    'Głogów Huta', 
    ['Głogów Huta', 'Głuszyca', 'Głogów Wróblin', 'Głogów', 'Żary'], 
    't', 
    pd.Timestamp("2026-12-11 11:00:00"), 
    names_passed=True,
    sample_neighbors=True
)
print_paths(result)
# Out:
# Fastest arrival: 2026-12-12 06:21:00
#
# Best city order:
# 	1. Głogów Huta
# 	2. Głuszyca
# 	3. Żary
# 	4. Głogów
# 	5. Głogów Wróblin
# 	6. Głogów Huta
# Execution time:		0.201442 seconds
# Minimized value:	2026-12-12 06:21:00 seconds

# %%
cities = [
    'Żary', 'Wrocław Główny', 'Bardo Śląskie', 'Żagań', 'Brzeg Dolny',
    'Legnica','Jaworzyna Śląska','Świdnica Miasto','Wałbrzych Miasto','Wałbrzych Główny',
    'Jelenia Góra', 'Szklarska Poręba Górna','Gryfów Śląski','Lubań Śląski','Zgorzelec',
    'Bolesławiec','Lubin', 'Głogów','Wołów',  'Środa Śląska',
    'Kłodzko Główne', 'Polanica-Zdrój',  'Duszniki-Zdrój',  'Kudowa-Zdrój', 'Ząbkowice Śląskie'
]

random.shuffle(cities)

print("CITIES:")
for i, city in enumerate(cities):
    print(f"\t{i}: {city}")

result = tabu_a(
    'Wrocław Główny', 
    cities,
    't', 
    pd.Timestamp("2026-05-11 11:00:00"), 
    names_passed=True,
    should_log=True,
    sample_neighbors=True
)

print_paths(result)
# Out:
# CITIES:
# 	0: Głogów
# 	1: Żary
# 	2: Lubań Śląski
# 	3: Świdnica Miasto
# 	4: Jaworzyna Śląska
# 	5: Szklarska Poręba Górna
# 	6: Jelenia Góra
# 	7: Duszniki-Zdrój
# 	8: Ząbkowice Śląskie
# 	9: Gryfów Śląski
# 	10: Legnica
# 	11: Brzeg Dolny
# 	12: Żagań
# 	13: Kłodzko Główne
# 	14: Środa Śląska
# 	15: Lubin
# 	16: Zgorzelec
# 	17: Wałbrzych Miasto
# 	18: Polanica-Zdrój
# 	19: Bolesławiec
# 	20: Wałbrzych Główny
# 	21: Wrocław Główny
# 	22: Kudowa-Zdrój
# 	23: Wołów
# 	24: Bardo Śląskie
#
# TRACKING PROGRESS:
# 	Best score: 2026-05-15 08:06:00
# 	Best score: 2026-05-14 22:37:00
# 	Best score: 2026-05-14 20:01:00
# 	Best score: 2026-05-14 18:26:00
# 	Best score: 2026-05-14 14:59:00
# 	Best score: 2026-05-14 10:44:00
# 	Best score: 2026-05-14 08:34:00
# 	Best score: 2026-05-13 23:13:00
# 	Best score: 2026-05-13 21:16:00
# 	Best score: 2026-05-13 16:05:00
# 	Best score: 2026-05-13 15:24:00
# 	Best score: 2026-05-13 13:13:00
# 	Best score: 2026-05-13 11:34:00
# 	Best score: 2026-05-13 09:43:00
# 	Best score: 2026-05-13 08:09:00
# 	Best score: 2026-05-13 07:04:00
#
# Fastest arrival: 2026-05-13 07:04:00
#
# Best city order:
# 	1. Wrocław Główny
# 	2. Żary
# 	3. Żagań
# 	4. Wołów
# 	5. Wałbrzych Główny
# 	6. Środa Śląska
# 	7. Bolesławiec
# 	8. Lubań Śląski
# 	9. Gryfów Śląski
# 	10. Zgorzelec
# 	11. Wałbrzych Miasto
# 	12. Jelenia Góra
# 	13. Szklarska Poręba Górna
# 	14. Jaworzyna Śląska
# 	15. Świdnica Miasto
# 	16. Ząbkowice Śląskie
# 	17. Kłodzko Główne
# 	18. Bardo Śląskie
# 	19. Kudowa-Zdrój
# 	20. Duszniki-Zdrój
# 	21. Polanica-Zdrój
# 	22. Legnica
# 	23. Lubin
# 	24. Głogów
# 	25. Brzeg Dolny
# 	26. Wrocław Główny
# Execution time:		35.030049 seconds
# Minimized value:	2026-05-13 07:04:00 seconds
