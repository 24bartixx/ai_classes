# %%
from pathlib import Path
import sys
import random

import pandas as pd

project_root = Path.cwd()
if not (project_root / "src").exists():
    project_root = project_root.parent

if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

from src.tabu_a import *
from src.graph import *
from src.utils import print_paths

# %%
test_time = pd.Timestamp("2026-10-09 11:00:00")
# graph = Graph(test_time, with_locations=True)
# restult = evaluate_solution_arr_time([1413424, 1413136, 1413137, 1413138, 1413139, 1413140, 1413141, 1413142, 1413144, 1413424, 1413136, 1413137, 1413138, 1413139, 1413140, 1413141, 1413142, 1413144, 1413424, 1413136, 1413137, 1413138, 1413139, 1413140, 1413141, 1413142, 1413144, 1413424, 1413136, 1413137, 1413138, 1413139, 1413140, 1413141, 1413142, 1413144, 1413424, 1413136, 1413137, 1413138, 1413139, 1413140, 1413141, 1413142, 1413144, 1413424, 1413136], graph, test_time, should_log=True)

# print(str(restult))

# %%
test_time = pd.Timestamp("2026-12-11 11:00:00")
# graph = Graph(test_time, with_locations=True)
# restult2 = evaluate_solution_arr_time([1413424, 1413136, 1413137, 1413138, 1413139, 1413140, 1413141, 1413142, 1413144, 1413424, 1413136, 1413137, 1413138, 1413139, 1413140, 1413141, 1413142, 1413144, 1413424, 1413136, 1413137, 1413138, 1413139, 1413140, 1413141, 1413142], graph, test_time, should_log=True)

# print(str(restult2))

# %%
test_time = pd.Timestamp("2026-07-03 11:00:00")
result = tabu_a(
    1413137, 
    [1413139, 1413137, 1413136, 1413138 , 1413424], 
    't', 
    pd.Timestamp("2026-12-11 11:00:00"),
    should_aspiration=True
)

print_paths(result)
# Out:
# Fastest arrival: 2026-12-12 06:21:00
#
# Best city order:
# 	1. 1413137
# 	2. 1413139
# 	3. 1413424
# 	4. 1413136
# 	5. 1413138
# 	6. 1413137
# Execution time:		0.230242 seconds
# Minimized value:	2026-12-12 06:21:00 seconds

# %%
result = tabu_a(
    'Głogów Huta', 
    ['Głogów Huta', 'Głuszyca', 'Głogów Wróblin', 'Głogów', 'Żary'], 
    't', 
    pd.Timestamp("2026-12-11 11:00:00"), 
    names_passed=True,
    should_aspiration=True
)
print_paths(result)
# Out:
# Fastest arrival: 2026-12-12 06:21:00
#
# Best city order:
# 	1. Głogów Huta
# 	2. Głuszyca
# 	3. Żary
# 	4. Głogów
# 	5. Głogów Wróblin
# 	6. Głogów Huta
# Execution time:		0.211768 seconds
# Minimized value:	2026-12-12 06:21:00 seconds

# %%
cities = [
    'Żary', 'Wrocław Główny', 'Bardo Śląskie', 'Żagań', 'Brzeg Dolny',
    'Legnica','Jaworzyna Śląska','Świdnica Miasto','Wałbrzych Miasto','Wałbrzych Główny',
    'Jelenia Góra', 'Szklarska Poręba Górna','Gryfów Śląski','Lubań Śląski','Zgorzelec',
    'Bolesławiec','Lubin', 'Głogów','Wołów',  'Środa Śląska',
    'Kłodzko Główne', 'Polanica-Zdrój',  'Duszniki-Zdrój',  'Kudowa-Zdrój', 'Ząbkowice Śląskie'
]

random.shuffle(cities)

print("CITIES:")
for i, city in enumerate(cities):
    print(f"\t{i}: {city}")

result = tabu_a(
    'Wrocław Główny', 
    cities,
    't', 
    pd.Timestamp("2026-05-11 11:00:00"), 
    names_passed=True,
    should_log=True,
    should_aspiration=True
)

print_paths(result)
# Out:
# CITIES:
# 	0: Wałbrzych Miasto
# 	1: Wołów
# 	2: Żagań
# 	3: Jaworzyna Śląska
# 	4: Ząbkowice Śląskie
# 	5: Świdnica Miasto
# 	6: Środa Śląska
# 	7: Bardo Śląskie
# 	8: Gryfów Śląski
# 	9: Kudowa-Zdrój
# 	10: Żary
# 	11: Bolesławiec
# 	12: Zgorzelec
# 	13: Brzeg Dolny
# 	14: Jelenia Góra
# 	15: Wałbrzych Główny
# 	16: Duszniki-Zdrój
# 	17: Szklarska Poręba Górna
# 	18: Legnica
# 	19: Kłodzko Główne
# 	20: Wrocław Główny
# 	21: Lubin
# 	22: Polanica-Zdrój
# 	23: Głogów
# 	24: Lubań Śląski
#
# TRACKING PROGRESS:
# 	Best score: 2026-05-15 07:09:00
# 	Best score: 2026-05-14 23:31:00
# 	Best score: 2026-05-14 19:33:00
#
# Fastest arrival: 2026-05-14 19:33:00
#
# Best city order:
# 	1. Wrocław Główny
# 	2. Szklarska Poręba Górna
# 	3. Żary
# 	4. Bolesławiec
# 	5. Zgorzelec
# 	6. Brzeg Dolny
# 	7. Jelenia Góra
# 	8. Wałbrzych Główny
# 	9. Duszniki-Zdrój
# 	10. Kudowa-Zdrój
# 	11. Gryfów Śląski
# 	12. Bardo Śląskie
# 	13. Środa Śląska
# 	14. Świdnica Miasto
# 	15. Ząbkowice Śląskie
# 	16. Jaworzyna Śląska
# 	17. Żagań
# 	18. Wołów
# 	19. Legnica
# 	20. Lubin
# 	21. Wałbrzych Miasto
# 	22. Kłodzko Główne
# 	23. Polanica-Zdrój
# 	24. Głogów
# 	25. Lubań Śląski
# 	26. Wrocław Główny
# Execution time:		29.206722 seconds
# Minimized value:	2026-05-14 19:33:00 seconds
