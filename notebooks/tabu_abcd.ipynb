# %%
from pathlib import Path
import sys
import random

import pandas as pd

project_root = Path.cwd()
if not (project_root / "src").exists():
    project_root = project_root.parent

if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

from src.tabu_a import *
from src.graph import *
from src.utils import print_paths

# %%
test_time = pd.Timestamp("2026-10-09 11:00:00")
# graph = Graph(test_time, with_locations=True)
# restult = evaluate_solution_arr_time([1413424, 1413136, 1413137, 1413138, 1413139, 1413140, 1413141, 1413142, 1413144, 1413424, 1413136, 1413137, 1413138, 1413139, 1413140, 1413141, 1413142, 1413144, 1413424, 1413136, 1413137, 1413138, 1413139, 1413140, 1413141, 1413142, 1413144, 1413424, 1413136, 1413137, 1413138, 1413139, 1413140, 1413141, 1413142, 1413144, 1413424, 1413136, 1413137, 1413138, 1413139, 1413140, 1413141, 1413142, 1413144, 1413424, 1413136], graph, test_time, should_log=True)

# print(str(restult))

# %%
test_time = pd.Timestamp("2026-12-11 11:00:00")
# graph = Graph(test_time, with_locations=True)
# restult2 = evaluate_solution_arr_time([1413424, 1413136, 1413137, 1413138, 1413139, 1413140, 1413141, 1413142, 1413144, 1413424, 1413136, 1413137, 1413138, 1413139, 1413140, 1413141, 1413142, 1413144, 1413424, 1413136, 1413137, 1413138, 1413139, 1413140, 1413141, 1413142], graph, test_time, should_log=True)

# print(str(restult2))

# %%
test_time = pd.Timestamp("2026-07-03 11:00:00")
result = tabu_a(
    1413137, 
    [1413139, 1413137, 1413136, 1413138 , 1413424], 
    't', 
    pd.Timestamp("2026-12-11 11:00:00"),
    limited_tabu_size=True,
    should_aspiration=True,
    sample_neighbors=True
)
# print_paths(result, should_print_path=True)
print_paths(result)
# Out:
# New best score: 2026-12-12 06:21:00 at iteration with no change count: 2
# Fastest arrival: 2026-12-12 06:21:00
#
# Best city order:
# 	1. 1413137
# 	2. 1413136
# 	3. 1413139
# 	4. 1413424
# 	5. 1413138
# 	6. 1413137
# Execution time:		0.308313 seconds
# Minimized value:	2026-12-12 06:21:00 seconds

# %%
result = tabu_a(
    'Głogów Huta', 
    ['Głuszyca', 'Głogów Huta', 'Głogów Wróblin', 'Głogów', 'Żary'], 
    't', 
    pd.Timestamp("2026-12-11 11:00:00"), 
    names_passed=True,
    limited_tabu_size=True,
    should_aspiration=True,
    sample_neighbors=True
)
print_paths(result)
# Out:
# New best score: 2026-12-12 06:21:00 at iteration with no change count: 2
# Fastest arrival: 2026-12-12 06:21:00
#
# Best city order:
# 	1. Głogów Huta
# 	2. Głuszyca
# 	3. Żary
# 	4. Głogów
# 	5. Głogów Wróblin
# 	6. Głogów Huta
# Execution time:		0.310769 seconds
# Minimized value:	2026-12-12 06:21:00 seconds

# %%
cities = [
    'Żary', 'Wrocław Główny', 'Bardo Śląskie', 'Żagań', 'Brzeg Dolny',
    'Legnica','Jaworzyna Śląska','Świdnica Miasto','Wałbrzych Miasto','Wałbrzych Główny',
    'Jelenia Góra', 'Szklarska Poręba Górna','Gryfów Śląski','Lubań Śląski','Zgorzelec',
    'Bolesławiec','Lubin', 'Głogów','Wołów',  'Środa Śląska',
    'Kłodzko Główne', 'Polanica-Zdrój',  'Duszniki-Zdrój',  'Kudowa-Zdrój', 'Ząbkowice Śląskie'
]

random.shuffle(cities)

print("CITIES:")
for i, city in enumerate(cities):
    print(f"\t{i}: {city}")

result = tabu_a(
    'Wrocław Główny', 
    cities,
    't', 
    pd.Timestamp("2026-05-11 11:00:00"), 
    names_passed=True,
    should_log=True,
    limited_tabu_size=True,
    should_aspiration=True,
    sample_neighbors=True
)

print_paths(result)
# Out:
# CITIES:
# 	0: Szklarska Poręba Górna
# 	1: Polanica-Zdrój
# 	2: Bolesławiec
# 	3: Gryfów Śląski
# 	4: Wałbrzych Główny
# 	5: Środa Śląska
# 	6: Głogów
# 	7: Wałbrzych Miasto
# 	8: Jaworzyna Śląska
# 	9: Lubin
# 	10: Kudowa-Zdrój
# 	11: Kłodzko Główne
# 	12: Bardo Śląskie
# 	13: Legnica
# 	14: Świdnica Miasto
# 	15: Żagań
# 	16: Jelenia Góra
# 	17: Wołów
# 	18: Lubań Śląski
# 	19: Ząbkowice Śląskie
# 	20: Brzeg Dolny
# 	21: Duszniki-Zdrój
# 	22: Wrocław Główny
# 	23: Zgorzelec
# 	24: Żary
# New best score: 2026-05-14 15:33:00 at iteration with no change count: 1
# New best score: 2026-05-14 00:11:00 at iteration with no change count: 1
# New best score: 2026-05-13 23:31:00 at iteration with no change count: 1
# New best score: 2026-05-13 22:37:00 at iteration with no change count: 1
# New best score: 2026-05-13 18:58:00 at iteration with no change count: 1
# New best score: 2026-05-13 12:43:00 at iteration with no change count: 2
# New best score: 2026-05-13 07:04:00 at iteration with no change count: 2
# New best score: 2026-05-12 22:37:00 at iteration with no change count: 3
# New best score: 2026-05-12 20:23:00 at iteration with no change count: 2
# New best score: 2026-05-12 20:01:00 at iteration with no change count: 4
# New best score: 2026-05-12 18:26:00 at iteration with no change count: 17
# New best score: 2026-05-12 17:04:00 at iteration with no change count: 9
#
# Fastest arrival: 2026-05-12 17:04:00
#
# Best city order:
# 	1. Wrocław Główny
# 	2. Jelenia Góra
# 	3. Szklarska Poręba Górna
# 	4. Wałbrzych Główny
# 	5. Wałbrzych Miasto
# 	6. Jaworzyna Śląska
# 	7. Świdnica Miasto
# 	8. Ząbkowice Śląskie
# 	9. Bardo Śląskie
# 	10. Polanica-Zdrój
# 	11. Kudowa-Zdrój
# 	12. Duszniki-Zdrój
# 	13. Kłodzko Główne
# 	14. Środa Śląska
# 	15. Legnica
# 	16. Lubań Śląski
# 	17. Gryfów Śląski
# 	18. Zgorzelec
# 	19. Bolesławiec
# 	20. Żary
# 	21. Żagań
# 	22. Lubin
# 	23. Głogów
# 	24. Wołów
# 	25. Brzeg Dolny
# 	26. Wrocław Główny
# Execution time:		257.500855 seconds
# Minimized value:	2026-05-12 17:04:00 seconds
