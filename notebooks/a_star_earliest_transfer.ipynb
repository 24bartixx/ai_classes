# %%
from pathlib import Path
import sys

import pandas as pd

project_root = Path.cwd()
if not (project_root / "src").exists():
    project_root = project_root.parent

if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

from src.a_star_earliest import a_star
from src.utils import print_path, print_lines

# %%
# Żary --> Głogów
# Przez Zieloną górę szybciej, ale to Polregio a nie KD...
path = a_star(1413424, 1413136, 'p', pd.Timestamp("2026-07-07"))
print_lines(path)
# Out:
# Optimal path: 05:35:00 - 09:19:00
#
# Lines used: D14, D20
# Minimized value:	1 transfers
# Execution time:		0.194199 seconds

# %%
# Żary --> Głogów
# Przez Zieloną górę szybciej, ale to Polregio a nie KD...
path = a_star(1413424, 1413136, 'p', pd.Timestamp("2026-07-07 17:00:00"))
print_lines(path)
# Out:
# Optimal path: 18:22:00 - 22:11:00
#
# Lines used: D14, D11
# Minimized value:	3 transfers
# Execution time:		0.045149 seconds

# %%
# Żary --> Głogów
# Przez Zieloną górę szybciej, ale to Polregio a nie KD...
path = a_star(1413424, 1413136, 'p', pd.Timestamp("2026-07-07 22:00:00"))
print_lines(path)
# Out:
# Optimal path: 05:35:00 - 09:19:00
#
# Lines used: D14, D20
# Minimized value:	1 transfers
# Execution time:		0.274605 seconds

# %%
# Żagań --> Wrocław Główny
path = a_star(1413422, 1413380, 'p', pd.Timestamp("2026-03-10"))
print_lines(path)
# Out:
# Optimal path: 05:51:00 - 07:48:00
#
# Lines used: D14
# Minimized value:	0 transfers
# Execution time:		0.041106 seconds

# %%
# Żary --> Brzeg Dolny
path = a_star(1413424, 1413092, 'p', pd.Timestamp("2026-07-07"))
print_lines(path)
# Out:
# Optimal path: 05:35:00 - 08:20:00
#
# Lines used: D14, D20
# Minimized value:	1 transfers
# Execution time:		0.061260 seconds

# %%
# Zgorzelec --> Strzelin
path = a_star(1413417, 1413326, 'p', pd.Timestamp("2026-07-07"))
print_lines(path)
# Out:
# Minimized value:	1 transfers
# Optimal path: 04:36:00 - 07:38:00
#
# Lines used: D10, D9
# Execution time:		0.104206 seconds

# %%
# Rawicz --> Wałbrzych Główny
path = a_star(1413291, 1413365, 'p', pd.Timestamp("2026-07-07 15:45:00"))
print_lines(path)
# Out:
# Minimized value:	1 transfers
# Optimal path: 19:38:00 - 21:59:00
#
# Lines used: D30, D6
# Execution time:		0.073750 seconds

# %%
# Zgorzelec --> Strzelin
path = a_star(1413417, 1413326, 'p', pd.Timestamp("2026-12-12 20:30:34"))
print_lines(path)
# Out:
# No available connections for given time
# Minimized value:	inf transfers
# Execution time:		0.032762 seconds

# %%
# Zgorzelec --> Strzelin
path = a_star(1413417, 1413326, 'p', pd.Timestamp("2025-12-12 20:30:34"))
print_lines(path)
# Out:
# No available connections for given time
# Minimized value:	inf transfers
# Execution time:		0.000231 seconds
