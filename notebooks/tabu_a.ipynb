# %%
from pathlib import Path
import sys
import random

import pandas as pd

project_root = Path.cwd()
if not (project_root / "src").exists():
    project_root = project_root.parent

if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

from src.tabu_a import *
from src.graph import *
from src.utils import print_paths

# %%
test_time = pd.Timestamp("2026-10-09 11:00:00")
# graph = Graph(test_time, with_locations=True)
# restult = evaluate_solution_arr_time([1413424, 1413136, 1413137, 1413138, 1413139, 1413140, 1413141, 1413142, 1413144, 1413424, 1413136, 1413137, 1413138, 1413139, 1413140, 1413141, 1413142, 1413144, 1413424, 1413136, 1413137, 1413138, 1413139, 1413140, 1413141, 1413142, 1413144, 1413424, 1413136, 1413137, 1413138, 1413139, 1413140, 1413141, 1413142, 1413144, 1413424, 1413136, 1413137, 1413138, 1413139, 1413140, 1413141, 1413142, 1413144, 1413424, 1413136], graph, test_time, should_log=True)

# print(str(restult))

# %%
test_time = pd.Timestamp("2026-12-11 11:00:00")
# graph = Graph(test_time, with_locations=True)
# restult2 = evaluate_solution_arr_time([1413424, 1413136, 1413137, 1413138, 1413139, 1413140, 1413141, 1413142, 1413144, 1413424, 1413136, 1413137, 1413138, 1413139, 1413140, 1413141, 1413142, 1413144, 1413424, 1413136, 1413137, 1413138, 1413139, 1413140, 1413141, 1413142], graph, test_time, should_log=True)

# print(str(restult2))

# %%
test_time = pd.Timestamp("2026-07-03 11:00:00")
result = tabu_a(
    1413137, 
    [1413139, 1413137, 1413136, 1413138 , 1413424], 
    't', 
    pd.Timestamp("2026-12-11 11:00:00")
)
# print_paths(result, should_print_path=True)
print_paths(result)
# Out:
# Fastest arrival: 2026-12-12 06:21:00
#
# Best city order:
# 	1. 1413137
# 	2. 1413139
# 	3. 1413424
# 	4. 1413136
# 	5. 1413138
# 	6. 1413137
# Execution time:		0.215489 seconds
# Minimized value:	2026-12-12 06:21:00 seconds

# %%
result = tabu_a(
    'Głogów Huta', 
    ['Głuszyca', 'Głogów Huta', 'Głogów Wróblin', 'Głogów', 'Żary'], 
    't', 
    pd.Timestamp("2026-12-11 11:00:00"), 
    names_passed=True
)
print_paths(result)
# Out:
# Fastest arrival: 2026-12-12 06:21:00
#
# Best city order:
# 	1. Głogów Huta
# 	2. Głuszyca
# 	3. Żary
# 	4. Głogów
# 	5. Głogów Wróblin
# 	6. Głogów Huta
# Execution time:		0.201828 seconds
# Minimized value:	2026-12-12 06:21:00 seconds

# %%
cities = [
    'Żary', 'Wrocław Główny', 'Bardo Śląskie', 'Żagań', 'Brzeg Dolny',
    'Legnica','Jaworzyna Śląska','Świdnica Miasto','Wałbrzych Miasto','Wałbrzych Główny',
    'Jelenia Góra', 'Szklarska Poręba Górna','Gryfów Śląski','Lubań Śląski','Zgorzelec',
    'Bolesławiec','Lubin', 'Głogów','Wołów',  'Środa Śląska',
    'Kłodzko Główne', 'Polanica-Zdrój',  'Duszniki-Zdrój',  'Kudowa-Zdrój', 'Ząbkowice Śląskie'
]

random.shuffle(cities)

print("CITIES:")
for i, city in enumerate(cities):
    print(f"\t{i}: {city}")

result = tabu_a(
    'Wrocław Główny', 
    cities,
    't', 
    pd.Timestamp("2026-05-11 11:00:00"), 
    names_passed=True,
    should_log=True
)

print_paths(result)
# Out:
# CITIES:
# 	0: Głogów
# 	1: Ząbkowice Śląskie
# 	2: Gryfów Śląski
# 	3: Kudowa-Zdrój
# 	4: Jelenia Góra
# 	5: Wałbrzych Miasto
# 	6: Lubań Śląski
# 	7: Kłodzko Główne
# 	8: Szklarska Poręba Górna
# 	9: Bolesławiec
# 	10: Środa Śląska
# 	11: Lubin
# 	12: Żary
# 	13: Świdnica Miasto
# 	14: Jaworzyna Śląska
# 	15: Zgorzelec
# 	16: Polanica-Zdrój
# 	17: Brzeg Dolny
# 	18: Żagań
# 	19: Wołów
# 	20: Wrocław Główny
# 	21: Wałbrzych Główny
# 	22: Bardo Śląskie
# 	23: Duszniki-Zdrój
# 	24: Legnica
#
# TRACKING PROGRESS:
# 	Best score: 2026-05-15 11:34:00
# 	Best score: 2026-05-15 04:20:00
# 	Best score: 2026-05-14 15:38:00
# 	Best score: 2026-05-14 11:34:00
# 	Best score: 2026-05-13 17:54:00
# 	Best score: 2026-05-13 15:38:00
# 	Best score: 2026-05-13 13:59:00
#
# Fastest arrival: 2026-05-13 13:59:00
#
# Best city order:
# 	1. Wrocław Główny
# 	2. Jaworzyna Śląska
# 	3. Wałbrzych Miasto
# 	4. Jelenia Góra
# 	5. Zgorzelec
# 	6. Lubań Śląski
# 	7. Gryfów Śląski
# 	8. Szklarska Poręba Górna
# 	9. Bolesławiec
# 	10. Środa Śląska
# 	11. Lubin
# 	12. Brzeg Dolny
# 	13. Polanica-Zdrój
# 	14. Kudowa-Zdrój
# 	15. Kłodzko Główne
# 	16. Ząbkowice Śląskie
# 	17. Świdnica Miasto
# 	18. Żary
# 	19. Żagań
# 	20. Wołów
# 	21. Głogów
# 	22. Wałbrzych Główny
# 	23. Legnica
# 	24. Duszniki-Zdrój
# 	25. Bardo Śląskie
# 	26. Wrocław Główny
# Execution time:		22.566376 seconds
# Minimized value:	2026-05-13 13:59:00 seconds
