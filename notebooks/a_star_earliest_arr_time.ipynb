# %%
from pathlib import Path
import sys

import pandas as pd

project_root = Path.cwd()
if not (project_root / "src").exists():
    project_root = project_root.parent

if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

from src.a_star_earliest import a_star
from src.utils import print_path

# %%
# Żary --> Głogów
# Przez Zieloną górę szybciej, ale to Polregio a nie KD...
# path = a_star('Żary', 'Głogów', 't', pd.Timestamp("2026-07-07"))
path = a_star(1413424, 1413136, 't', pd.Timestamp("2026-07-07"))
print_path(path)
# Out:
# Optimal path: 05:35:00 - 09:19:00
#
# Line:		D14
# Stops:		Żary ---> Żagań
# Dates:		2026-07-07 - 2026-07-07
# Times:		05:35:00 - 05:47:00
#
# Line:		D14
# Stops:		Żagań ---> Małomice
# Dates:		2026-07-07 - 2026-07-07
# Times:		05:48:00 - 05:56:00
#
# Line:		D14
# Stops:		Małomice ---> Leszno Górne
# Dates:		2026-07-07 - 2026-07-07
# Times:		05:57:00 - 06:08:00
#
# Line:		D14
# Stops:		Leszno Górne ---> Wierzbowa Śląska
# Dates:		2026-07-07 - 2026-07-07
# Times:		06:08:00 - 06:19:00
#
# Line:		D14
# Stops:		Wierzbowa Śląska ---> Modła
# Dates:		2026-07-07 - 2026-07-07
# Times:		06:19:00 - 06:23:00
#
# Line:		D14
# Stops:		Modła ---> Rokitki
# Dates:		2026-07-07 - 2026-07-07
# Times:		06:24:00 - 06:30:00
#
# Line:		D14
# Stops:		Rokitki ---> Miłkowice
# Dates:		2026-07-07 - 2026-07-07
# Times:		06:31:00 - 06:43:00
#
# Line:		D14
# Stops:		Miłkowice ---> Jezierzany
# Dates:		2026-07-07 - 2026-07-07
# Times:		06:43:00 - 06:47:00
#
# Line:		D14
# Stops:		Jezierzany ---> Legnica
# ...

# %%
# Żary --> Głogów
# Przez Zieloną górę szybciej, ale to Polregio a nie KD...
path = a_star(1413424, 1413136, 't', pd.Timestamp("2026-07-07 17:00:00"))
print_path(path)
# Out:
# Optimal path: 18:22:00 - 22:11:00
#
# Line:		D14
# Stops:		Żary ---> Żagań
# Dates:		2026-07-07 - 2026-07-07
# Times:		18:22:00 - 18:33:00
#
# Line:		D14
# Stops:		Żagań ---> Małomice
# Dates:		2026-07-07 - 2026-07-07
# Times:		18:34:00 - 18:42:00
#
# Line:		D14
# Stops:		Małomice ---> Leszno Górne
# Dates:		2026-07-07 - 2026-07-07
# Times:		18:43:00 - 18:55:00
#
# Line:		D14
# Stops:		Leszno Górne ---> Wierzbowa Śląska
# Dates:		2026-07-07 - 2026-07-07
# Times:		18:55:00 - 19:06:00
#
# Line:		D14
# Stops:		Wierzbowa Śląska ---> Modła
# Dates:		2026-07-07 - 2026-07-07
# Times:		19:07:00 - 19:11:00
#
# Line:		D14
# Stops:		Modła ---> Rokitki
# Dates:		2026-07-07 - 2026-07-07
# Times:		19:11:00 - 19:18:00
#
# Line:		D14
# Stops:		Rokitki ---> Biała Górna
# Dates:		2026-07-07 - 2026-07-07
# Times:		19:18:00 - 19:24:00
#
# Line:		D14
# Stops:		Biała Górna ---> Chojnów
# Dates:		2026-07-07 - 2026-07-07
# Times:		19:24:00 - 19:28:00
#
# Line:		D14
# Stops:		Chojnów ---> Miłkowice
# ...

# %%
# Żary --> Głogów
# Przez Zieloną górę szybciej, ale to Polregio a nie KD...
path = a_star(1413424, 1413136, 't', pd.Timestamp("2026-07-07 22:00:00"))
print_path(path)
# Out:
# Optimal path: 05:35:00 - 09:19:00
#
# Line:		D14
# Stops:		Żary ---> Żagań
# Dates:		2026-07-08 - 2026-07-08
# Times:		05:35:00 - 05:47:00
#
# Line:		D14
# Stops:		Żagań ---> Małomice
# Dates:		2026-07-08 - 2026-07-08
# Times:		05:48:00 - 05:56:00
#
# Line:		D14
# Stops:		Małomice ---> Leszno Górne
# Dates:		2026-07-08 - 2026-07-08
# Times:		05:57:00 - 06:08:00
#
# Line:		D14
# Stops:		Leszno Górne ---> Wierzbowa Śląska
# Dates:		2026-07-08 - 2026-07-08
# Times:		06:08:00 - 06:19:00
#
# Line:		D14
# Stops:		Wierzbowa Śląska ---> Modła
# Dates:		2026-07-08 - 2026-07-08
# Times:		06:19:00 - 06:23:00
#
# Line:		D14
# Stops:		Modła ---> Rokitki
# Dates:		2026-07-08 - 2026-07-08
# Times:		06:24:00 - 06:30:00
#
# Line:		D14
# Stops:		Rokitki ---> Miłkowice
# Dates:		2026-07-08 - 2026-07-08
# Times:		06:31:00 - 06:43:00
#
# Line:		D14
# Stops:		Miłkowice ---> Jezierzany
# Dates:		2026-07-08 - 2026-07-08
# Times:		06:43:00 - 06:47:00
#
# Line:		D14
# Stops:		Jezierzany ---> Legnica
# ...

# %%
# Żagań --> Wrocław Główny
path = a_star(1413422, 1413380, 't', pd.Timestamp("2026-03-10"))
print_path(path)
# Out:
# Optimal path: 05:51:00 - 07:48:00
#
# Line:		D14
# Stops:		Żagań ---> Małomice
# Dates:		2026-03-10 - 2026-03-10
# Times:		05:51:00 - 05:59:00
#
# Line:		D14
# Stops:		Małomice ---> Leszno Górne
# Dates:		2026-03-10 - 2026-03-10
# Times:		06:00:00 - 06:11:00
#
# Line:		D14
# Stops:		Leszno Górne ---> Wierzbowa Śląska
# Dates:		2026-03-10 - 2026-03-10
# Times:		06:11:00 - 06:21:00
#
# Line:		D14
# Stops:		Wierzbowa Śląska ---> Modła
# Dates:		2026-03-10 - 2026-03-10
# Times:		06:21:00 - 06:25:00
#
# Line:		D14
# Stops:		Modła ---> Rokitki
# Dates:		2026-03-10 - 2026-03-10
# Times:		06:26:00 - 06:32:00
#
# Line:		D14
# Stops:		Rokitki ---> Miłkowice
# Dates:		2026-03-10 - 2026-03-10
# Times:		06:33:00 - 06:43:00
#
# Line:		D14
# Stops:		Miłkowice ---> Jezierzany
# Dates:		2026-03-10 - 2026-03-10
# Times:		06:43:00 - 06:47:00
#
# Line:		D14
# Stops:		Jezierzany ---> Legnica
# Dates:		2026-03-10 - 2026-03-10
# Times:		06:47:00 - 06:53:00
#
# Line:		D14
# ...

# %%
# Żary --> Brzeg Dolny
path = a_star(1413424, 1413092, 't', pd.Timestamp("2026-07-07"))
print_path(path)
# Out:
# Optimal path: 05:35:00 - 08:20:00
#
# Line:		D14
# Stops:		Żary ---> Żagań
# Dates:		2026-07-07 - 2026-07-07
# Times:		05:35:00 - 05:47:00
#
# Line:		D14
# Stops:		Żagań ---> Małomice
# Dates:		2026-07-07 - 2026-07-07
# Times:		05:48:00 - 05:56:00
#
# Line:		D14
# Stops:		Małomice ---> Leszno Górne
# Dates:		2026-07-07 - 2026-07-07
# Times:		05:57:00 - 06:08:00
#
# Line:		D14
# Stops:		Leszno Górne ---> Wierzbowa Śląska
# Dates:		2026-07-07 - 2026-07-07
# Times:		06:08:00 - 06:19:00
#
# Line:		D14
# Stops:		Wierzbowa Śląska ---> Modła
# Dates:		2026-07-07 - 2026-07-07
# Times:		06:19:00 - 06:23:00
#
# Line:		D14
# Stops:		Modła ---> Rokitki
# Dates:		2026-07-07 - 2026-07-07
# Times:		06:24:00 - 06:30:00
#
# Line:		D14
# Stops:		Rokitki ---> Miłkowice
# Dates:		2026-07-07 - 2026-07-07
# Times:		06:31:00 - 06:43:00
#
# Line:		D14
# Stops:		Miłkowice ---> Jezierzany
# Dates:		2026-07-07 - 2026-07-07
# Times:		06:43:00 - 06:47:00
#
# Line:		D14
# Stops:		Jezierzany ---> Legnica
# ...

# %%
# Zgorzelec --> Strzelin
path = a_star(1413417, 1413326, 't', pd.Timestamp("2026-07-07"))
print_path(path)
# Out:
# Optimal path: 04:36:00 - 07:38:00
#
# Line:		D10
# Stops:		Zgorzelec ---> Zgorzelec Miasto
# Dates:		2026-07-07 - 2026-07-07
# Times:		04:36:00 - 04:38:00
#
# Line:		D10
# Stops:		Zgorzelec Miasto ---> Jędrzychowice
# Dates:		2026-07-07 - 2026-07-07
# Times:		04:39:00 - 04:41:00
#
# Line:		D10
# Stops:		Jędrzychowice ---> Pieńsk
# Dates:		2026-07-07 - 2026-07-07
# Times:		04:41:00 - 04:46:00
#
# Line:		D10
# Stops:		Pieńsk ---> Węgliniec
# Dates:		2026-07-07 - 2026-07-07
# Times:		04:47:00 - 04:55:00
#
# Line:		D10
# Stops:		Węgliniec ---> Zagajnik
# Dates:		2026-07-07 - 2026-07-07
# Times:		04:56:00 - 05:00:00
#
# Line:		D10
# Stops:		Zagajnik ---> Zebrzydowa
# Dates:		2026-07-07 - 2026-07-07
# Times:		05:00:00 - 05:05:00
#
# Line:		D10
# Stops:		Zebrzydowa ---> Bolesławiec
# Dates:		2026-07-07 - 2026-07-07
# Times:		05:05:00 - 05:13:00
#
# Line:		D10
# Stops:		Bolesławiec ---> Tomaszów Bolesławiecki
# Dates:		2026-07-07 - 2026-07-07
# Times:		05:14:00 - 05:19:00
#
# Line:		D10
# ...

# %%
# Rawicz --> Wałbrzych Główny
path = a_star(1413291, 1413365, 't', pd.Timestamp("2026-07-07 15:45:00"))
print_path(path)
# Out:
# Optimal path: 16:34:00 - 19:12:00
#
# Line:		D3/D9
# Stops:		Rawicz ---> Korzeńsko
# Dates:		2026-07-07 - 2026-07-07
# Times:		16:34:00 - 16:39:00
#
# Line:		D3/D9
# Stops:		Korzeńsko ---> Garbce
# Dates:		2026-07-07 - 2026-07-07
# Times:		16:40:00 - 16:42:00
#
# Line:		D3/D9
# Stops:		Garbce ---> Żmigród
# Dates:		2026-07-07 - 2026-07-07
# Times:		16:43:00 - 16:46:00
#
# Line:		D3/D9
# Stops:		Żmigród ---> Skokowa
# Dates:		2026-07-07 - 2026-07-07
# Times:		16:47:00 - 16:53:00
#
# Line:		D3/D9
# Stops:		Skokowa ---> Osola
# Dates:		2026-07-07 - 2026-07-07
# Times:		16:53:00 - 16:57:00
#
# Line:		D3/D9
# Stops:		Osola ---> Oborniki Śląskie
# Dates:		2026-07-07 - 2026-07-07
# Times:		16:57:00 - 17:01:00
#
# Line:		D3/D9
# Stops:		Oborniki Śląskie ---> Pęgów
# Dates:		2026-07-07 - 2026-07-07
# Times:		17:02:00 - 17:06:00
#
# Line:		D3/D9
# Stops:		Pęgów ---> Szewce
# Dates:		2026-07-07 - 2026-07-07
# Times:		17:06:00 - 17:09:00
#
# Line:		D3/D9
# Stops:		Szewce ---> Wrocław Świniary
# ...

# %%
# Wałbrzych Główny --> 
path = a_star(1413365 , 1413422, 't', pd.Timestamp("2026-04-30 20:00:00"))
print_path(path)
# Out:
# Optimal path: 20:16:00 - 07:20:00
#
# Line:		D60
# Stops:		Wałbrzych Główny ---> Wałbrzych Fabryczny
# Dates:		2026-04-30 - 2026-04-30
# Times:		20:16:00 - 20:20:00
#
# Line:		D60
# Stops:		Wałbrzych Fabryczny ---> Wałbrzych Centrum
# Dates:		2026-04-30 - 2026-04-30
# Times:		20:23:00 - 20:27:00
#
# Line:		D60
# Stops:		Wałbrzych Centrum ---> Wałbrzych Miasto
# Dates:		2026-04-30 - 2026-04-30
# Times:		20:27:00 - 20:30:00
#
# Line:		D60
# Stops:		Wałbrzych Miasto ---> Wałbrzych Szczawienko
# Dates:		2026-04-30 - 2026-04-30
# Times:		20:31:00 - 20:35:00
#
# Line:		D60
# Stops:		Wałbrzych Szczawienko ---> Świebodzice
# Dates:		2026-04-30 - 2026-04-30
# Times:		20:36:00 - 20:45:00
#
# Line:		D60
# Stops:		Świebodzice ---> Jaworzyna Śląska
# Dates:		2026-04-30 - 2026-04-30
# Times:		20:45:00 - 20:52:00
#
# Line:		nan
# Stops:		Jaworzyna Śląska ---> Stanowice
# Dates:		2026-04-30 - 2026-04-30
# Times:		21:26:00 - 21:31:00
#
# Line:		nan
# Stops:		Stanowice ---> Strzegom
# ...

# %%
path = a_star('Wałbrzych Główny' , 'Żagań', 't', pd.Timestamp("2026-04-30 20:00:00"), names_passed=True)
print_path(path)
# Out:
# Optimal path: 20:16:00 - 07:20:00
#
# Line:		D60
# Stops:		Wałbrzych Główny ---> Wałbrzych Fabryczny
# Dates:		2026-04-30 - 2026-04-30
# Times:		20:16:00 - 20:20:00
#
# Line:		D60
# Stops:		Wałbrzych Fabryczny ---> Wałbrzych Centrum
# Dates:		2026-04-30 - 2026-04-30
# Times:		20:23:00 - 20:27:00
#
# Line:		D60
# Stops:		Wałbrzych Centrum ---> Wałbrzych Miasto
# Dates:		2026-04-30 - 2026-04-30
# Times:		20:27:00 - 20:30:00
#
# Line:		D60
# Stops:		Wałbrzych Miasto ---> Wałbrzych Szczawienko
# Dates:		2026-04-30 - 2026-04-30
# Times:		20:31:00 - 20:35:00
#
# Line:		D60
# Stops:		Wałbrzych Szczawienko ---> Świebodzice
# Dates:		2026-04-30 - 2026-04-30
# Times:		20:36:00 - 20:45:00
#
# Line:		D60
# Stops:		Świebodzice ---> Jaworzyna Śląska
# Dates:		2026-04-30 - 2026-04-30
# Times:		20:45:00 - 20:52:00
#
# Line:		nan
# Stops:		Jaworzyna Śląska ---> Stanowice
# Dates:		2026-04-30 - 2026-04-30
# Times:		21:26:00 - 21:31:00
#
# Line:		nan
# Stops:		Stanowice ---> Strzegom
# ...

# %%
# Zgorzelec --> Strzelin
path = a_star(1413417, 1413326, 't', pd.Timestamp("2026-12-12 20:30:34"))
print_path(path)
# Out:
# No available connections for given time

# %%
# Zgorzelec --> Strzelin
path = a_star(1413417, 1413326, 't', pd.Timestamp("2025-12-12 20:30:34"))
print_path(path)
# Out:
# No available connections for given time

# %%
path = a_star(1413144 , 1413424, 't', pd.Timestamp("2026-12-12 18:09:00"))
print_path(path)
# Out:
# No available connections for given time

# %%
path = a_star(1807626 , 1413164, 't', pd.Timestamp("2026-04-30 20:00:00"))
print_path(path)
# Out:
# No available connections for given time

# %%
path = a_star(1474777 , 1474777, 't', pd.Timestamp("2026-04-30 20:00:00"))
print_path(path)
# Out:
# Optimal path: 20:00:00 - 20:00:00
#
# Line:		---
# Stops:		1474777 ---> 1474777
# Dates:		2026-04-30 - 2026-04-30
# Times:		20:00:00 - 20:00:00
