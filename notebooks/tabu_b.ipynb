# %%
from pathlib import Path
import sys
import random

import pandas as pd

project_root = Path.cwd()
if not (project_root / "src").exists():
    project_root = project_root.parent

if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

from src.tabu_a import *
from src.graph import *
from src.utils import print_paths

# %%
test_time = pd.Timestamp("2026-10-09 11:00:00")
# graph = Graph(test_time, with_locations=True)
# restult = evaluate_solution_arr_time([1413424, 1413136, 1413137, 1413138, 1413139, 1413140, 1413141, 1413142, 1413144, 1413424, 1413136, 1413137, 1413138, 1413139, 1413140, 1413141, 1413142, 1413144, 1413424, 1413136, 1413137, 1413138, 1413139, 1413140, 1413141, 1413142, 1413144, 1413424, 1413136, 1413137, 1413138, 1413139, 1413140, 1413141, 1413142, 1413144, 1413424, 1413136, 1413137, 1413138, 1413139, 1413140, 1413141, 1413142, 1413144, 1413424, 1413136], graph, test_time, should_log=True)

# print(str(restult))

# %%
test_time = pd.Timestamp("2026-12-11 11:00:00")
# graph = Graph(test_time, with_locations=True)
# restult2 = evaluate_solution_arr_time([1413424, 1413136, 1413137, 1413138, 1413139, 1413140, 1413141, 1413142, 1413144, 1413424, 1413136, 1413137, 1413138, 1413139, 1413140, 1413141, 1413142, 1413144, 1413424, 1413136, 1413137, 1413138, 1413139, 1413140, 1413141, 1413142], graph, test_time, should_log=True)

# print(str(restult2))

# %%
test_time = pd.Timestamp("2026-07-03 11:00:00")
result = tabu_a(
    1413137, 
    [1413139, 1413137, 1413136, 1413138 , 1413424], 
    't', 
    pd.Timestamp("2026-12-11 11:00:00"),
    limited_tabu_size=True
)

print_paths(result)
# Out:
# Fastest arrival: 2026-12-12 06:21:00
#
# Best city order:
# 	1. 1413137
# 	2. 1413139
# 	3. 1413424
# 	4. 1413136
# 	5. 1413138
# 	6. 1413137
# Execution time:		0.195702 seconds
# Minimized value:	2026-12-12 06:21:00 seconds

# %%
result = tabu_a(
    'Głogów Huta', 
    ['Głogów Huta', 'Głuszyca', 'Głogów Wróblin', 'Głogów', 'Żary'], 
    't', 
    pd.Timestamp("2026-12-11 11:00:00"), 
    names_passed=True,
    limited_tabu_size=True
)
print_paths(result)
# Out:
# Fastest arrival: 2026-12-12 06:21:00
#
# Best city order:
# 	1. Głogów Huta
# 	2. Głuszyca
# 	3. Żary
# 	4. Głogów
# 	5. Głogów Wróblin
# 	6. Głogów Huta
# Execution time:		0.190068 seconds
# Minimized value:	2026-12-12 06:21:00 seconds

# %%
cities = [
    'Żary', 'Wrocław Główny', 'Bardo Śląskie', 'Żagań', 'Brzeg Dolny',
    'Legnica','Jaworzyna Śląska','Świdnica Miasto','Wałbrzych Miasto','Wałbrzych Główny',
    'Jelenia Góra', 'Szklarska Poręba Górna','Gryfów Śląski','Lubań Śląski','Zgorzelec',
    'Bolesławiec','Lubin', 'Głogów','Wołów',  'Środa Śląska',
    'Kłodzko Główne', 'Polanica-Zdrój',  'Duszniki-Zdrój',  'Kudowa-Zdrój', 'Ząbkowice Śląskie'
]

random.shuffle(cities)

print("CITIES:")
for i, city in enumerate(cities):
    print(f"\t{i}: {city}")

result = tabu_a(
    'Wrocław Główny', 
    cities,
    't', 
    pd.Timestamp("2026-05-11 11:00:00"), 
    names_passed=True,
    should_log=True,
    limited_tabu_size=True
)

print_paths(result)
# Out:
# CITIES:
# 	0: Świdnica Miasto
# 	1: Głogów
# 	2: Lubin
# 	3: Wołów
# 	4: Duszniki-Zdrój
# 	5: Wałbrzych Miasto
# 	6: Wałbrzych Główny
# 	7: Szklarska Poręba Górna
# 	8: Kłodzko Główne
# 	9: Żary
# 	10: Bolesławiec
# 	11: Bardo Śląskie
# 	12: Jaworzyna Śląska
# 	13: Lubań Śląski
# 	14: Polanica-Zdrój
# 	15: Brzeg Dolny
# 	16: Żagań
# 	17: Wrocław Główny
# 	18: Legnica
# 	19: Jelenia Góra
# 	20: Kudowa-Zdrój
# 	21: Zgorzelec
# 	22: Ząbkowice Śląskie
# 	23: Gryfów Śląski
# 	24: Środa Śląska
#
# TRACKING PROGRESS:
# 	Best score: 2026-05-15 00:11:00
# 	Best score: 2026-05-14 21:59:00
# 	Best score: 2026-05-14 15:03:00
# 	Best score: 2026-05-14 10:23:00
# 	Best score: 2026-05-14 07:48:00
# 	Best score: 2026-05-13 20:44:00
#
# Fastest arrival: 2026-05-13 20:44:00
#
# Best city order:
# 	1. Wrocław Główny
# 	2. Głogów
# 	3. Lubin
# 	4. Wołów
# 	5. Duszniki-Zdrój
# 	6. Wałbrzych Miasto
# 	7. Wałbrzych Główny
# 	8. Szklarska Poręba Górna
# 	9. Kłodzko Główne
# 	10. Kudowa-Zdrój
# 	11. Polanica-Zdrój
# 	12. Brzeg Dolny
# 	13. Żagań
# 	14. Legnica
# 	15. Świdnica Miasto
# 	16. Ząbkowice Śląskie
# 	17. Zgorzelec
# 	18. Gryfów Śląski
# 	19. Jelenia Góra
# 	20. Lubań Śląski
# 	21. Bolesławiec
# 	22. Bardo Śląskie
# 	23. Jaworzyna Śląska
# 	24. Żary
# 	25. Środa Śląska
# 	26. Wrocław Główny
# Execution time:		19.647783 seconds
# Minimized value:	2026-05-13 20:44:00 seconds
