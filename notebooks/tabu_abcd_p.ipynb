# %%
from pathlib import Path
import sys
import random

import pandas as pd

project_root = Path.cwd()
if not (project_root / "src").exists():
    project_root = project_root.parent

if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

from src.tabu_a import *
from src.graph import *
from src.utils import print_paths

# %%
result = tabu_a(
    'Legnica', 
    ['Jawor', 'Wrocław Główny', 'Wałbrzych Główny', 'Legnica', 'Kąty Wrocławskie'], 
    'p', 
    pd.Timestamp("2026-12-11 11:00:00"), 
    names_passed=True,
    limited_tabu_size=True,
    should_aspiration=True,
    sample_neighbors=True
)

print_paths(result)
# Out:
# New best score: 2026-12-11 15:47:00 at iteration with no change count: 2
# Fastest arrival: 2026-12-11 15:47:00
#
# Best city order:
# 	1. Legnica
# 	2. Jawor
# 	3. Wałbrzych Główny
# 	4. Kąty Wrocławskie
# 	5. Wrocław Główny
# 	6. Legnica
# Execution time:		15.872285 seconds
# Minimized value:	2026-12-11 15:47:00 seconds
