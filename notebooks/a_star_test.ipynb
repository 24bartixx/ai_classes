# %%
from pathlib import Path
import sys

import pandas as pd

project_root = Path.cwd()
if not (project_root / "src").exists():
    project_root = project_root.parent

if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

from src.a_star import a_star
from src.utils import print_path

# %%
# Żagań --> Wrocław Główny
path = a_star(1413422, 1413380, None, pd.Timestamp("2026-03-10"))
print_path(path)
# Out:
# FINISHED
# Optimal path: 05:51:00 - 07:48:00
#
# D14	05:51:00 - 05:59:00	Żagań ---> Małomice
# D14	06:00:00 - 06:11:00	Małomice ---> Leszno Górne
# D14	06:11:00 - 06:21:00	Leszno Górne ---> Wierzbowa Śląska
# D14	06:21:00 - 06:25:00	Wierzbowa Śląska ---> Modła
# D14	06:26:00 - 06:32:00	Modła ---> Rokitki
# D14	06:33:00 - 06:43:00	Rokitki ---> Miłkowice
# D14	06:43:00 - 06:47:00	Miłkowice ---> Jezierzany
# D14	06:47:00 - 06:53:00	Jezierzany ---> Legnica
# D14	07:03:00 - 07:21:00	Legnica ---> Środa Śląska
# D14	07:22:00 - 07:38:00	Środa Śląska ---> Wrocław Nowy Dwór
# D14	07:39:00 - 07:41:00	Wrocław Nowy Dwór ---> Wrocław Muchobór
# D14	07:42:00 - 07:48:00	Wrocław Muchobór ---> Wrocław Główny

# %%
# Żary --> Głogów
# Przez Zieloną górę szybciej, ale to Polregio a nie KD...
path = a_star(1413424, 1413136, None, pd.Timestamp("2026-07-07"))
print_path(path)
# Out:
# FINISHED
# Optimal path: 07:42:00 - 10:56:00
#
# D14	07:42:00 - 07:53:00	Żary ---> Żagań
# D14	07:54:00 - 08:03:00	Żagań ---> Małomice
# D14	08:03:00 - 08:15:00	Małomice ---> Leszno Górne
# D14	08:15:00 - 08:26:00	Leszno Górne ---> Wierzbowa Śląska
# D14	08:26:00 - 08:30:00	Wierzbowa Śląska ---> Modła
# D14	08:31:00 - 08:37:00	Modła ---> Rokitki
# D14	08:38:00 - 08:50:00	Rokitki ---> Miłkowice
# D14	08:51:00 - 08:55:00	Miłkowice ---> Jezierzany
# D14	08:55:00 - 09:01:00	Jezierzany ---> Legnica
# D12	09:57:00 - 10:01:00	Legnica ---> Rzeszotary
# D12	10:02:00 - 10:06:00	Rzeszotary ---> Raszówka
# D12	10:13:00 - 10:16:00	Raszówka ---> Gorzelin
# D12	10:16:00 - 10:19:00	Gorzelin ---> Chróstnik
# D12	10:19:00 - 10:23:00	Chróstnik ---> Lubin
# D12	10:24:00 - 10:26:00	Lubin ---> Lubin Stadion
# D12	10:26:00 - 10:30:00	Lubin Stadion ---> Koźlice
# D12	10:30:00 - 10:33:00	Koźlice ---> Rynarcice
# D12	10:33:00 - 10:36:00	Rynarcice ---> Rudna Miasto
# ...

# %%
# Żary --> Brzeg Dolny
path = a_star(1413424, 1413092, None, pd.Timestamp("2026-07-07"))
print_path(path)
# Out:
# FINISHED
# Optimal path: 07:42:00 - 10:20:00
#
# D14	07:42:00 - 07:53:00	Żary ---> Żagań
# D14	07:54:00 - 08:03:00	Żagań ---> Małomice
# D14	08:03:00 - 08:15:00	Małomice ---> Leszno Górne
# D14	08:15:00 - 08:26:00	Leszno Górne ---> Wierzbowa Śląska
# D14	08:26:00 - 08:30:00	Wierzbowa Śląska ---> Modła
# D14	08:31:00 - 08:37:00	Modła ---> Rokitki
# D14	08:38:00 - 08:50:00	Rokitki ---> Miłkowice
# D14	08:51:00 - 08:55:00	Miłkowice ---> Jezierzany
# D14	08:55:00 - 09:01:00	Jezierzany ---> Legnica
# D10	09:06:00 - 09:21:00	Legnica ---> Środa Śląska
# D10	09:21:00 - 09:34:00	Środa Śląska ---> Wrocław Nowy Dwór
# D10	09:35:00 - 09:37:00	Wrocław Nowy Dwór ---> Wrocław Muchobór
# D2	09:55:00 - 09:58:00	Wrocław Muchobór ---> Wrocław Kuźniki
# D2	09:58:00 - 10:00:00	Wrocław Kuźniki ---> Wrocław Stadion
# D2	10:01:00 - 10:04:00	Wrocław Stadion ---> Wrocław Pracze
# D2	10:04:00 - 10:09:00	Wrocław Pracze ---> Brzezinka Średzka
# D2	10:10:00 - 10:12:00	Brzezinka Średzka ---> Czerna Mała
# ...

# %%
# Zgorzelec --> Strzelin
path = a_star(1413417, 1413326, None, pd.Timestamp("2026-07-07"))
print_path(path)
# Out:
# FINISHED
# Optimal path: 04:36:00 - 07:38:00
#
# D10	04:36:00 - 04:38:00	Zgorzelec ---> Zgorzelec Miasto
# D10	04:39:00 - 04:41:00	Zgorzelec Miasto ---> Jędrzychowice
# D10	04:41:00 - 04:46:00	Jędrzychowice ---> Pieńsk
# D10	04:47:00 - 04:55:00	Pieńsk ---> Węgliniec
# D10	04:56:00 - 05:00:00	Węgliniec ---> Zagajnik
# D10	05:00:00 - 05:05:00	Zagajnik ---> Zebrzydowa
# D10	05:05:00 - 05:13:00	Zebrzydowa ---> Bolesławiec
# D10	05:14:00 - 05:19:00	Bolesławiec ---> Tomaszów Bolesławiecki
# D10	05:20:00 - 05:24:00	Tomaszów Bolesławiecki ---> Okmiany
# D10	05:25:00 - 05:28:00	Okmiany ---> Osetnica
# D10	05:29:00 - 05:33:00	Osetnica ---> Chojnów
# D10	05:34:00 - 05:40:00	Chojnów ---> Miłkowice
# D10	05:40:00 - 05:48:00	Miłkowice ---> Legnica
# D10	05:50:00 - 05:54:00	Legnica ---> Kunice
# D10	05:55:00 - 05:58:00	Kunice ---> Jaśkowice Legnickie
# D10	05:58:00 - 06:01:00	Jaśkowice Legnickie ---> Szczedrzykowice
# D10	06:01:00 - 06:07:00	Szczedrzykowice ---> Malczyce
# ...

# %%
# Rawicz --> Wałbrzych Główny
path = a_star(1413291, 1413365, None, pd.Timestamp("2026-07-07"))
print_path(path)
# Out:
# FINISHED
# Optimal path: 14:17:00 - 16:32:00
#
# D30	14:17:00 - 14:24:00	Rawicz ---> Żmigród
# D30	14:25:00 - 14:35:00	Żmigród ---> Oborniki Śląskie
# D30	14:36:00 - 14:46:00	Oborniki Śląskie ---> Wrocław Mikołajów
# D30	14:47:00 - 14:52:00	Wrocław Mikołajów ---> Wrocław Główny
# D60	15:10:00 - 15:15:00	Wrocław Główny ---> Wrocław Grabiszyn
# D60	15:16:00 - 15:18:00	Wrocław Grabiszyn ---> Wrocław Zachodni
# D60	15:18:00 - 15:21:00	Wrocław Zachodni ---> Mokronos Górny
# D60	15:21:00 - 15:24:00	Mokronos Górny ---> Smolec
# D60	15:24:00 - 15:27:00	Smolec ---> Sadowice Wrocławskie
# D60	15:28:00 - 15:32:00	Sadowice Wrocławskie ---> Kąty Wrocławskie
# D60	15:33:00 - 15:39:00	Kąty Wrocławskie ---> Mietków
# D60	15:39:00 - 15:43:00	Mietków ---> Imbramowice
# D60	15:44:00 - 15:49:00	Imbramowice ---> Żarów
# D60	15:49:00 - 15:54:00	Żarów ---> Jaworzyna Śląska
# D60	15:55:00 - 16:02:00	Jaworzyna Śląska ---> Świebodzice
# D60	16:02:00 - 16:12:00	Świebodzice ---> Wałbrzych Szczawienko
# ...
