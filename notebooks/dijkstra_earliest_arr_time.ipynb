# %%
from pathlib import Path
import sys

import pandas as pd

project_root = Path.cwd()
if not (project_root / "src").exists():
    project_root = project_root.parent

if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

from src.dijikstra_earliest_in_day import dijkstra
from src.utils import print_path

# %%
# Żagań --> Wrocław Główny
result = dijkstra(1413422, 1413380, 't', pd.Timestamp("2026-03-10"))
print_path(result)
# Out:
# Optimal path: 05:51:00 - 07:48:00
#
# Line:		D14
# Stops:		Żagań ---> Małomice
# Dates:		2026-03-10 - 2026-03-10
# Times:		05:51:00 - 05:59:00
#
# Line:		D14
# Stops:		Małomice ---> Leszno Górne
# Dates:		2026-03-10 - 2026-03-10
# Times:		06:00:00 - 06:11:00
#
# Line:		D14
# Stops:		Leszno Górne ---> Wierzbowa Śląska
# Dates:		2026-03-10 - 2026-03-10
# Times:		06:11:00 - 06:21:00
#
# Line:		D14
# Stops:		Wierzbowa Śląska ---> Modła
# Dates:		2026-03-10 - 2026-03-10
# Times:		06:21:00 - 06:25:00
#
# Line:		D14
# Stops:		Modła ---> Rokitki
# Dates:		2026-03-10 - 2026-03-10
# Times:		06:26:00 - 06:32:00
#
# Line:		D14
# Stops:		Rokitki ---> Miłkowice
# Dates:		2026-03-10 - 2026-03-10
# Times:		06:33:00 - 06:43:00
#
# Line:		D14
# Stops:		Miłkowice ---> Jezierzany
# Dates:		2026-03-10 - 2026-03-10
# Times:		06:43:00 - 06:47:00
#
# Line:		D14
# Stops:		Jezierzany ---> Legnica
# Dates:		2026-03-10 - 2026-03-10
# Times:		06:47:00 - 06:53:00
#
# Line:		D14
# Stops:		Legnica ---> Środa Śląska
# Dates:		2026-03-10 - 2026-03-10
# Times:		07:03:00 - 07:21:00
#
# Line:		D14
# Stops:		Środa Śląska ---> Wrocław Nowy Dwór
# Dates:		2026-03-10 - 2026-03-10
# Times:		07:22:00 - 07:38:00
#
# Line:		D14
# Stops:		Wrocław Nowy Dwór ---> Wrocław Muchobór
# Dates:		2026-03-10 - 2026-03-10
# Times:		07:39:00 - 07:41:00
#
# Line:		D14
# Stops:		Wrocław Muchobór ---> Wrocław Główny
# Dates:		2026-03-10 - 2026-03-10
# Times:		07:42:00 - 07:48:00

# %%
# Żagań --> Wrocław Główny
path = dijkstra(1413422, 1413380, 't', pd.Timestamp("2026-03-10 17:00:00"))
print_path(path)
# Out:
# Optimal path: 17:33:00 - 19:21:00
#
# Line:		D14
# Stops:		Żagań ---> Małomice
# Dates:		2026-03-10 - 2026-03-10
# Times:		17:33:00 - 17:41:00
#
# Line:		D14
# Stops:		Małomice ---> Leszno Górne
# Dates:		2026-03-10 - 2026-03-10
# Times:		17:42:00 - 17:53:00
#
# Line:		D14
# Stops:		Leszno Górne ---> Wierzbowa Śląska
# Dates:		2026-03-10 - 2026-03-10
# Times:		17:53:00 - 18:02:00
#
# Line:		D14
# Stops:		Wierzbowa Śląska ---> Modła
# Dates:		2026-03-10 - 2026-03-10
# Times:		18:02:00 - 18:06:00
#
# Line:		D14
# Stops:		Modła ---> Rokitki
# Dates:		2026-03-10 - 2026-03-10
# Times:		18:06:00 - 18:11:00
#
# Line:		D14
# Stops:		Rokitki ---> Miłkowice
# Dates:		2026-03-10 - 2026-03-10
# Times:		18:12:00 - 18:21:00
#
# Line:		D14
# Stops:		Miłkowice ---> Jezierzany
# Dates:		2026-03-10 - 2026-03-10
# Times:		18:22:00 - 18:25:00
#
# Line:		D14
# Stops:		Jezierzany ---> Legnica
# Dates:		2026-03-10 - 2026-03-10
# Times:		18:25:00 - 18:30:00
#
# Line:		D14
# Stops:		Legnica ---> Środa Śląska
# Dates:		2026-03-10 - 2026-03-10
# Times:		18:31:00 - 18:50:00
#
# Line:		D14
# Stops:		Środa Śląska ---> Wrocław Nowy Dwór
# Dates:		2026-03-10 - 2026-03-10
# Times:		18:52:00 - 19:09:00
#
# Line:		D14
# Stops:		Wrocław Nowy Dwór ---> Wrocław Muchobór
# Dates:		2026-03-10 - 2026-03-10
# Times:		19:12:00 - 19:15:00
#
# Line:		D14
# Stops:		Wrocław Muchobór ---> Wrocław Główny
# Dates:		2026-03-10 - 2026-03-10
# Times:		19:15:00 - 19:21:00

# %%
# Żagań --> Wrocław Główny
path = dijkstra(1413422, 1413380, 't', pd.Timestamp("2026-03-10 21:00:00"))
print_path(path)
# Out:
# Optimal path: 05:51:00 - 07:48:00
#
# Line:		D14
# Stops:		Żagań ---> Małomice
# Dates:		2026-03-11 - 2026-03-11
# Times:		05:51:00 - 05:59:00
#
# Line:		D14
# Stops:		Małomice ---> Leszno Górne
# Dates:		2026-03-11 - 2026-03-11
# Times:		06:00:00 - 06:11:00
#
# Line:		D14
# Stops:		Leszno Górne ---> Wierzbowa Śląska
# Dates:		2026-03-11 - 2026-03-11
# Times:		06:11:00 - 06:21:00
#
# Line:		D14
# Stops:		Wierzbowa Śląska ---> Modła
# Dates:		2026-03-11 - 2026-03-11
# Times:		06:21:00 - 06:25:00
#
# Line:		D14
# Stops:		Modła ---> Rokitki
# Dates:		2026-03-11 - 2026-03-11
# Times:		06:26:00 - 06:32:00
#
# Line:		D14
# Stops:		Rokitki ---> Miłkowice
# Dates:		2026-03-11 - 2026-03-11
# Times:		06:33:00 - 06:43:00
#
# Line:		D14
# Stops:		Miłkowice ---> Jezierzany
# Dates:		2026-03-11 - 2026-03-11
# Times:		06:43:00 - 06:47:00
#
# Line:		D14
# Stops:		Jezierzany ---> Legnica
# Dates:		2026-03-11 - 2026-03-11
# Times:		06:47:00 - 06:53:00
#
# Line:		D14
# Stops:		Legnica ---> Środa Śląska
# Dates:		2026-03-11 - 2026-03-11
# Times:		07:03:00 - 07:21:00
#
# Line:		D14
# Stops:		Środa Śląska ---> Wrocław Nowy Dwór
# Dates:		2026-03-11 - 2026-03-11
# Times:		07:22:00 - 07:38:00
#
# Line:		D14
# Stops:		Wrocław Nowy Dwór ---> Wrocław Muchobór
# Dates:		2026-03-11 - 2026-03-11
# Times:		07:39:00 - 07:41:00
#
# Line:		D14
# Stops:		Wrocław Muchobór ---> Wrocław Główny
# Dates:		2026-03-11 - 2026-03-11
# Times:		07:42:00 - 07:48:00

# %%
# Żary --> Głogów
# Przez Zieloną górę szybciej, ale to Polregio a nie KD...
path = dijkstra(1413424, 1413136, 't', pd.Timestamp("2026-07-07"))
print(path)
print_path(path)
# Out:
# (datetime.date(2026, 7, 7), [{'to': 1413422, 'dep_time': 20100, 'arr_time': 20820, 'time': 720, 'trip_id': '37151991_400487', 'from_stop_name': 'Żary', 'to_stop_name': 'Żagań', 'line_name': 'D14', 'from_lat': 51.634465, 'from_lon': 15.137714, 'to_lat': 51.603766, 'to_lon': 15.315421}, {'to': 1413231, 'dep_time': 20880, 'arr_time': 21360, 'time': 480, 'trip_id': '37151991_400487', 'from_stop_name': 'Żagań', 'to_stop_name': 'Małomice', 'line_name': 'D14', 'from_lat': 51.603766, 'from_lon': 15.315421, 'to_lat': 51.549651, 'to_lon': 15.446928}, {'to': 1413213, 'dep_time': 21420, 'arr_time': 22080, 'time': 660, 'trip_id': '37151991_400487', 'from_stop_name': 'Małomice', 'to_stop_name': 'Leszno Górne', 'line_name': 'D14', 'from_lat': 51.549651, 'from_lon': 15.446928, 'to_lat': 51.466872, 'to_lon': 15.616046}, {'to': 1413374, 'dep_time': 22080, 'arr_time': 22740, 'time': 660, 'trip_id': '37151991_400487', 'from_stop_name': 'Leszno Górne', 'to_stop_name': 'Wierzbowa Śląska', 'line_name': 'D14', 'from_lat': 51.466872, 'from_lon': 15.616046, 'to_lat': 51.396904, 'to_lon': 15.758852}, {'to': 1413247, 'dep_time': 22740, 'arr_time': 22980, 'time': 240, 'trip_id': '37151991_400487', 'from_stop_name': 'Wierzbowa Śląska', 'to_stop_name': 'Modła', 'line_name': 'D14', 'from_lat': 51.396904, 'from_lon': 15.758852, 'to_lat': 51.375628, 'to_lon': 15.813586}, {'to': 1413296, 'dep_time': 23040, 'arr_time': 23400, 'time': 360, 'trip_id': '37151991_400487', 'from_stop_name': 'Modła', 'to_stop_name': 'Rokitki', 'line_name': 'D14', 'from_lat': 51.375628, 'from_lon': 15.813586, 'to_lat': 51.335419, 'to_lon': 15.893242}, {'to': 1413243, 'dep_time': 23460, 'arr_time': 24180, 'time': 720, 'trip_id': '37151991_400487', 'from_stop_name': 'Rokitki', 'to_stop_name': 'Miłkowice', 'line_name': 'D14', 'from_lat': 51.335419, 'from_lon': 15.893242, 'to_lat': 51.255565, 'to_lon': 16.054625}, {'to': 1413179, 'dep_time': 24180, 'arr_time': 24420, 'time': 240, 'trip_id': '37151991_400487', 'from_stop_name': 'Miłkowice', 'to_stop_name': 'Jezierzany', 'line_name': 'D14', 'from_lat': 51.255565, 'from_lon': 16.054625, 'to_lat': 51.235647, 'to_lon': 16.097664}, {'to': 1413210, 'dep_time': 24420, 'arr_time': 24780, 'time': 360, 'trip_id': '37151991_400487', 'from_stop_name': 'Jezierzany', 'to_stop_name': 'Legnica', 'line_name': 'D14', 'from_lat': 51.235647, 'from_lon': 16.097664, 'to_lat': 51.214097, 'to_lon': 16.16967}, {'to': 1413341, 'dep_time': 25380, 'arr_time': 26460, 'time': 1080, 'trip_id': '37151991_400487', 'from_stop_name': 'Legnica', 'to_stop_name': 'Środa Śląska', 'line_name': 'D14', 'from_lat': 51.214097, 'from_lon': 16.16967, 'to_lat': 51.189431, 'to_lon': 16.606723}, {'to': 1413388, 'dep_time': 26520, 'arr_time': 27480, 'time': 960, 'trip_id': '37151991_400487', 'from_stop_name': 'Środa Śląska', 'to_stop_name': 'Wrocław Nowy Dwór', 'line_name': 'D14', 'from_lat': 51.189431, 'from_lon': 16.606723, 'to_lat': 51.119688, 'to_lon': 16.955185}, {'to': 1413386, 'dep_time': 27540, 'arr_time': 27660, 'time': 120, 'trip_id': '37151991_400487', 'from_stop_name': 'Wrocław Nowy Dwór', 'to_stop_name': 'Wrocław Muchobór', 'line_name': 'D14', 'from_lat': 51.119688, 'from_lon': 16.955185, 'to_lat': 51.111064, 'to_lon': 16.974872}, {'to': 1413383, 'dep_time': 28500, 'arr_time': 28680, 'time': 180, 'trip_id': '37150239_398735', 'from_stop_name': 'Wrocław Muchobór', 'to_stop_name': 'Wrocław Kuźniki', 'line_name': 'D20', 'from_lat': 51.111064, 'from_lon': 16.974872, 'to_lat': 51.128026, 'to_lon': 16.952237}, {'to': 1413398, 'dep_time': 28680, 'arr_time': 28800, 'time': 120, 'trip_id': '37150239_398735', 'from_stop_name': 'Wrocław Kuźniki', 'to_stop_name': 'Wrocław Stadion', 'line_name': 'D20', 'from_lat': 51.128026, 'from_lon': 16.952237, 'to_lat': 51.137042, 'to_lon': 16.94064}, {'to': 1413394, 'dep_time': 28860, 'arr_time': 29040, 'time': 180, 'trip_id': '37150239_398735', 'from_stop_name': 'Wrocław Stadion', 'to_stop_name': 'Wrocław Pracze', 'line_name': 'D20', 'from_lat': 51.1 ...
# Optimal path: 05:35:00 - 09:19:00
#
# Line:		D14
# Stops:		Żary ---> Żagań
# Dates:		2026-07-07 - 2026-07-07
# Times:		05:35:00 - 05:47:00
#
# Line:		D14
# Stops:		Żagań ---> Małomice
# Dates:		2026-07-07 - 2026-07-07
# Times:		05:48:00 - 05:56:00
#
# Line:		D14
# Stops:		Małomice ---> Leszno Górne
# Dates:		2026-07-07 - 2026-07-07
# Times:		05:57:00 - 06:08:00
#
# Line:		D14
# Stops:		Leszno Górne ---> Wierzbowa Śląska
# Dates:		2026-07-07 - 2026-07-07
# Times:		06:08:00 - 06:19:00
#
# Line:		D14
# Stops:		Wierzbowa Śląska ---> Modła
# Dates:		2026-07-07 - 2026-07-07
# Times:		06:19:00 - 06:23:00
#
# Line:		D14
# Stops:		Modła ---> Rokitki
# Dates:		2026-07-07 - 2026-07-07
# Times:		06:24:00 - 06:30:00
#
# Line:		D14
# Stops:		Rokitki ---> Miłkowice
# Dates:		2026-07-07 - 2026-07-07
# Times:		06:31:00 - 06:43:00
#
# Line:		D14
# Stops:		Miłkowice ---> Jezierzany
# Dates:		2026-07-07 - 2026-07-07
# Times:		06:43:00 - 06:47:00
#
# Line:		D14
# Stops:		Jezierzany ---> Legnica
# Dates:		2026-07-07 - 2026-07-07
# Times:		06:47:00 - 06:53:00
#
# Line:		D14
# Stops:		Legnica ---> Środa Śląska
# Dates:		2026-07-07 - 2026-07-07
# Times:		07:03:00 - 07:21:00
#
# Line:		D14
# Stops:		Środa Śląska ---> Wrocław Nowy Dwór
# Dates:		2026-07-07 - 2026-07-07
# Times:		07:22:00 - 07:38:00
#
# Line:		D14
# Stops:		Wrocław Nowy Dwór ---> Wrocław Muchobór
# Dates:		2026-07-07 - 2026-07-07
# Times:		07:39:00 - 07:41:00
#
# Line:		D20
# Stops:		Wrocław Muchobór ---> Wrocław Kuźniki
# Dates:		2026-07-07 - 2026-07-07
# Times:		07:55:00 - 07:58:00
#
# Line:		D20
# Stops:		Wrocław Kuźniki ---> Wrocław Stadion
# Dates:		2026-07-07 - 2026-07-07
# Times:		07:58:00 - 08:00:00
#
# Line:		D20
# Stops:		Wrocław Stadion ---> Wrocław Pracze
# Dates:		2026-07-07 - 2026-07-07
# Times:		08:01:00 - 08:04:00
#
# Line:		D20
# Stops:		Wrocław Pracze ---> Brzezinka Średzka
# Dates:		2026-07-07 - 2026-07-07
# Times:		08:04:00 - 08:09:00
#
# Line:		D20
# Stops:		Brzezinka Średzka ---> Czerna Mała
# Dates:		2026-07-07 - 2026-07-07
# Times:		08:10:00 - 08:12:00
#
# Line:		D20
# Stops:		Czerna Mała ---> Księginice
# Dates:		2026-07-07 - 2026-07-07
# Times:		08:13:00 - 08:15:00
#
# Line:		D20
# Stops:		Księginice ---> Brzeg Dolny
# Dates:		2026-07-07 - 2026-07-07
# Times:		08:16:00 - 08:20:00
#
# Line:		D20
# Stops:		Brzeg Dolny ---> Łososiowice
# Dates:		2026-07-07 - 2026-07-07
# Times:		08:21:00 - 08:25:00
#
# Line:		D20
# Stops:		Łososiowice ---> Wołów
# Dates:		2026-07-07 - 2026-07-07
# Times:		08:25:00 - 08:29:00
#
# Line:		D20
# Stops:		Wołów ---> Orzeszków
# Dates:		2026-07-07 - 2026-07-07
# Times:		08:30:00 - 08:38:00
#
# Line:		D20
# Stops:		Orzeszków ---> Małowice Wołowskie
# Dates:		2026-07-07 - 2026-07-07
# Times:		08:39:00 - 08:41:00
#
# Line:		D20
# Stops:		Małowice Wołowskie ---> Ścinawa
# Dates:		2026-07-07 - 2026-07-07
# Times:		08:41:00 - 08:45:00
#
# Line:		D20
# Stops:		Ścinawa ---> Chełmek Wołowski
# Dates:		2026-07-07 - 2026-07-07
# Times:		08:46:00 - 08:51:00
#
# Line:		D20
# Stops:		Chełmek Wołowski ---> Rudna Miasto
# Dates:		2026-07-07 - 2026-07-07
# Times:		08:52:00 - 08:58:00
#
# Line:		D20
# Stops:		Rudna Miasto ---> Rudna Gwizdanów
# Dates:		2026-07-07 - 2026-07-07
# Times:		08:59:00 - 09:02:00
#
# Line:		D20
# Stops:		Rudna Gwizdanów ---> Grębocice
# Dates:		2026-07-07 - 2026-07-07
# Times:		09:02:00 - 09:09:00
#
# Line:		D20
# Stops:		Grębocice ---> Krzepów
# Dates:		2026-07-07 - 2026-07-07
# Times:		09:09:00 - 09:14:00
#
# Line:		D20
# Stops:		Krzepów ---> Głogów
# Dates:		2026-07-07 - 2026-07-07
# Times:		09:14:00 - 09:19:00

# %%
# Żary --> Brzeg Dolny
path = dijkstra(1413424, 1413092, 't', pd.Timestamp("2026-07-07"))
print_path(path)
# Out:
# Optimal path: 05:35:00 - 08:20:00
#
# Line:		D14
# Stops:		Żary ---> Żagań
# Dates:		2026-07-07 - 2026-07-07
# Times:		05:35:00 - 05:47:00
#
# Line:		D14
# Stops:		Żagań ---> Małomice
# Dates:		2026-07-07 - 2026-07-07
# Times:		05:48:00 - 05:56:00
#
# Line:		D14
# Stops:		Małomice ---> Leszno Górne
# Dates:		2026-07-07 - 2026-07-07
# Times:		05:57:00 - 06:08:00
#
# Line:		D14
# Stops:		Leszno Górne ---> Wierzbowa Śląska
# Dates:		2026-07-07 - 2026-07-07
# Times:		06:08:00 - 06:19:00
#
# Line:		D14
# Stops:		Wierzbowa Śląska ---> Modła
# Dates:		2026-07-07 - 2026-07-07
# Times:		06:19:00 - 06:23:00
#
# Line:		D14
# Stops:		Modła ---> Rokitki
# Dates:		2026-07-07 - 2026-07-07
# Times:		06:24:00 - 06:30:00
#
# Line:		D14
# Stops:		Rokitki ---> Miłkowice
# Dates:		2026-07-07 - 2026-07-07
# Times:		06:31:00 - 06:43:00
#
# Line:		D14
# Stops:		Miłkowice ---> Jezierzany
# Dates:		2026-07-07 - 2026-07-07
# Times:		06:43:00 - 06:47:00
#
# Line:		D14
# Stops:		Jezierzany ---> Legnica
# Dates:		2026-07-07 - 2026-07-07
# Times:		06:47:00 - 06:53:00
#
# Line:		D14
# Stops:		Legnica ---> Środa Śląska
# Dates:		2026-07-07 - 2026-07-07
# Times:		07:03:00 - 07:21:00
#
# Line:		D14
# Stops:		Środa Śląska ---> Wrocław Nowy Dwór
# Dates:		2026-07-07 - 2026-07-07
# Times:		07:22:00 - 07:38:00
#
# Line:		D14
# Stops:		Wrocław Nowy Dwór ---> Wrocław Muchobór
# Dates:		2026-07-07 - 2026-07-07
# Times:		07:39:00 - 07:41:00
#
# Line:		D20
# Stops:		Wrocław Muchobór ---> Wrocław Kuźniki
# Dates:		2026-07-07 - 2026-07-07
# Times:		07:55:00 - 07:58:00
#
# Line:		D20
# Stops:		Wrocław Kuźniki ---> Wrocław Stadion
# Dates:		2026-07-07 - 2026-07-07
# Times:		07:58:00 - 08:00:00
#
# Line:		D20
# Stops:		Wrocław Stadion ---> Wrocław Pracze
# Dates:		2026-07-07 - 2026-07-07
# Times:		08:01:00 - 08:04:00
#
# Line:		D20
# Stops:		Wrocław Pracze ---> Brzezinka Średzka
# Dates:		2026-07-07 - 2026-07-07
# Times:		08:04:00 - 08:09:00
#
# Line:		D20
# Stops:		Brzezinka Średzka ---> Czerna Mała
# Dates:		2026-07-07 - 2026-07-07
# Times:		08:10:00 - 08:12:00
#
# Line:		D20
# Stops:		Czerna Mała ---> Księginice
# Dates:		2026-07-07 - 2026-07-07
# Times:		08:13:00 - 08:15:00
#
# Line:		D20
# Stops:		Księginice ---> Brzeg Dolny
# Dates:		2026-07-07 - 2026-07-07
# Times:		08:16:00 - 08:20:00

# %%
# Zgorzelec --> Strzelin
path = dijkstra(1413417, 1413326, 't', pd.Timestamp("2026-07-07"))
print_path(path)
# Out:
# Optimal path: 04:36:00 - 07:38:00
#
# Line:		D10
# Stops:		Zgorzelec ---> Zgorzelec Miasto
# Dates:		2026-07-07 - 2026-07-07
# Times:		04:36:00 - 04:38:00
#
# Line:		D10
# Stops:		Zgorzelec Miasto ---> Jędrzychowice
# Dates:		2026-07-07 - 2026-07-07
# Times:		04:39:00 - 04:41:00
#
# Line:		D10
# Stops:		Jędrzychowice ---> Pieńsk
# Dates:		2026-07-07 - 2026-07-07
# Times:		04:41:00 - 04:46:00
#
# Line:		D10
# Stops:		Pieńsk ---> Węgliniec
# Dates:		2026-07-07 - 2026-07-07
# Times:		04:47:00 - 04:55:00
#
# Line:		D10
# Stops:		Węgliniec ---> Zagajnik
# Dates:		2026-07-07 - 2026-07-07
# Times:		04:56:00 - 05:00:00
#
# Line:		D10
# Stops:		Zagajnik ---> Zebrzydowa
# Dates:		2026-07-07 - 2026-07-07
# Times:		05:00:00 - 05:05:00
#
# Line:		D10
# Stops:		Zebrzydowa ---> Bolesławiec
# Dates:		2026-07-07 - 2026-07-07
# Times:		05:05:00 - 05:13:00
#
# Line:		D10
# Stops:		Bolesławiec ---> Tomaszów Bolesławiecki
# Dates:		2026-07-07 - 2026-07-07
# Times:		05:14:00 - 05:19:00
#
# Line:		D10
# Stops:		Tomaszów Bolesławiecki ---> Okmiany
# Dates:		2026-07-07 - 2026-07-07
# Times:		05:20:00 - 05:24:00
#
# Line:		D10
# Stops:		Okmiany ---> Osetnica
# Dates:		2026-07-07 - 2026-07-07
# Times:		05:25:00 - 05:28:00
#
# Line:		D10
# Stops:		Osetnica ---> Chojnów
# Dates:		2026-07-07 - 2026-07-07
# Times:		05:29:00 - 05:33:00
#
# Line:		D10
# Stops:		Chojnów ---> Miłkowice
# Dates:		2026-07-07 - 2026-07-07
# Times:		05:34:00 - 05:40:00
#
# Line:		D10
# Stops:		Miłkowice ---> Legnica
# Dates:		2026-07-07 - 2026-07-07
# Times:		05:40:00 - 05:48:00
#
# Line:		D10
# Stops:		Legnica ---> Kunice
# Dates:		2026-07-07 - 2026-07-07
# Times:		05:50:00 - 05:54:00
#
# Line:		D10
# Stops:		Kunice ---> Jaśkowice Legnickie
# Dates:		2026-07-07 - 2026-07-07
# Times:		05:55:00 - 05:58:00
#
# Line:		D10
# Stops:		Jaśkowice Legnickie ---> Szczedrzykowice
# Dates:		2026-07-07 - 2026-07-07
# Times:		05:58:00 - 06:01:00
#
# Line:		D10
# Stops:		Szczedrzykowice ---> Malczyce
# Dates:		2026-07-07 - 2026-07-07
# Times:		06:01:00 - 06:07:00
#
# Line:		D10
# Stops:		Malczyce ---> Środa Śląska
# Dates:		2026-07-07 - 2026-07-07
# Times:		06:07:00 - 06:13:00
#
# Line:		D10
# Stops:		Środa Śląska ---> Przedmoście Święte
# Dates:		2026-07-07 - 2026-07-07
# Times:		06:14:00 - 06:17:00
#
# Line:		D10
# Stops:		Przedmoście Święte ---> Miękinia
# Dates:		2026-07-07 - 2026-07-07
# Times:		06:18:00 - 06:21:00
#
# Line:		D10
# Stops:		Miękinia ---> Mrozów
# Dates:		2026-07-07 - 2026-07-07
# Times:		06:22:00 - 06:24:00
#
# Line:		D10
# Stops:		Mrozów ---> Wrocław Leśnica
# Dates:		2026-07-07 - 2026-07-07
# Times:		06:25:00 - 06:30:00
#
# Line:		D10
# Stops:		Wrocław Leśnica ---> Wrocław Żerniki
# Dates:		2026-07-07 - 2026-07-07
# Times:		06:31:00 - 06:34:00
#
# Line:		D10
# Stops:		Wrocław Żerniki ---> Wrocław Nowy Dwór
# Dates:		2026-07-07 - 2026-07-07
# Times:		06:34:00 - 06:37:00
#
# Line:		D10
# Stops:		Wrocław Nowy Dwór ---> Wrocław Muchobór
# Dates:		2026-07-07 - 2026-07-07
# Times:		06:38:00 - 06:40:00
#
# Line:		D10
# Stops:		Wrocław Muchobór ---> Wrocław Główny
# Dates:		2026-07-07 - 2026-07-07
# Times:		06:41:00 - 06:46:00
#
# Line:		D9
# Stops:		Wrocław Główny ---> Iwiny
# Dates:		2026-07-07 - 2026-07-07
# Times:		07:02:00 - 07:08:00
#
# Line:		D9
# Stops:		Iwiny ---> Smardzów Wrocławski
# Dates:		2026-07-07 - 2026-07-07
# Times:		07:08:00 - 07:11:00
#
# Line:		D9
# Stops:		Smardzów Wrocławski ---> Żórawina
# Dates:		2026-07-07 - 2026-07-07
# Times:		07:11:00 - 07:16:00
#
# Line:		D9
# Stops:		Żórawina ---> Węgry
# Dates:		2026-07-07 - 2026-07-07
# Times:		07:16:00 - 07:21:00
#
# Line:		D9
# Stops:		Węgry ---> Boreczek
# Dates:		2026-07-07 - 2026-07-07
# Times:		07:22:00 - 07:26:00
#
# Line:		D9
# Stops:		Boreczek ---> Warkocz
# Dates:		2026-07-07 - 2026-07-07
# Times:		07:27:00 - 07:31:00
#
# Line:		D9
# Stops:		Warkocz ---> Strzelin
# Dates:		2026-07-07 - 2026-07-07
# Times:		07:32:00 - 07:38:00

# %%
# Rawicz --> Wałbrzych Główny
path = dijkstra(1413291, 1413365, 't', pd.Timestamp("2026-07-07"))
print_path(path)
# Out:
# Optimal path: 04:18:00 - 07:34:00
#
# Line:		D3/D9
# Stops:		Rawicz ---> Korzeńsko
# Dates:		2026-07-07 - 2026-07-07
# Times:		04:18:00 - 04:23:00
#
# Line:		D3/D9
# Stops:		Korzeńsko ---> Garbce
# Dates:		2026-07-07 - 2026-07-07
# Times:		04:23:00 - 04:26:00
#
# Line:		D3/D9
# Stops:		Garbce ---> Żmigród
# Dates:		2026-07-07 - 2026-07-07
# Times:		04:27:00 - 04:30:00
#
# Line:		D3/D9
# Stops:		Żmigród ---> Skokowa
# Dates:		2026-07-07 - 2026-07-07
# Times:		04:31:00 - 04:37:00
#
# Line:		D3/D9
# Stops:		Skokowa ---> Osola
# Dates:		2026-07-07 - 2026-07-07
# Times:		04:38:00 - 04:41:00
#
# Line:		D3/D9
# Stops:		Osola ---> Oborniki Śląskie
# Dates:		2026-07-07 - 2026-07-07
# Times:		04:42:00 - 04:45:00
#
# Line:		D3/D9
# Stops:		Oborniki Śląskie ---> Pęgów
# Dates:		2026-07-07 - 2026-07-07
# Times:		04:46:00 - 04:51:00
#
# Line:		D3/D9
# Stops:		Pęgów ---> Szewce
# Dates:		2026-07-07 - 2026-07-07
# Times:		04:51:00 - 04:54:00
#
# Line:		D3/D9
# Stops:		Szewce ---> Wrocław Świniary
# Dates:		2026-07-07 - 2026-07-07
# Times:		04:55:00 - 04:57:00
#
# Line:		D3/D9
# Stops:		Wrocław Świniary ---> Wrocław Osobowice
# Dates:		2026-07-07 - 2026-07-07
# Times:		04:57:00 - 05:00:00
#
# Line:		D3/D9
# Stops:		Wrocław Osobowice ---> Wrocław Różanka
# Dates:		2026-07-07 - 2026-07-07
# Times:		05:00:00 - 05:03:00
#
# Line:		D3/D9
# Stops:		Wrocław Różanka ---> Wrocław Popowice
# Dates:		2026-07-07 - 2026-07-07
# Times:		05:04:00 - 05:05:00
#
# Line:		D3/D9
# Stops:		Wrocław Popowice ---> Wrocław Mikołajów
# Dates:		2026-07-07 - 2026-07-07
# Times:		05:06:00 - 05:07:00
#
# Line:		D3/D9
# Stops:		Wrocław Mikołajów ---> Wrocław Główny
# Dates:		2026-07-07 - 2026-07-07
# Times:		05:08:00 - 05:13:00
#
# Line:		D6
# Stops:		Wrocław Główny ---> Wrocław Grabiszyn
# Dates:		2026-07-07 - 2026-07-07
# Times:		06:10:00 - 06:15:00
#
# Line:		D6
# Stops:		Wrocław Grabiszyn ---> Wrocław Zachodni
# Dates:		2026-07-07 - 2026-07-07
# Times:		06:16:00 - 06:18:00
#
# Line:		D6
# Stops:		Wrocław Zachodni ---> Mokronos Górny
# Dates:		2026-07-07 - 2026-07-07
# Times:		06:18:00 - 06:21:00
#
# Line:		D6
# Stops:		Mokronos Górny ---> Smolec
# Dates:		2026-07-07 - 2026-07-07
# Times:		06:21:00 - 06:24:00
#
# Line:		D6
# Stops:		Smolec ---> Sadowice Wrocławskie
# Dates:		2026-07-07 - 2026-07-07
# Times:		06:24:00 - 06:27:00
#
# Line:		D6
# Stops:		Sadowice Wrocławskie ---> Kąty Wrocławskie
# Dates:		2026-07-07 - 2026-07-07
# Times:		06:28:00 - 06:32:00
#
# Line:		D6
# Stops:		Kąty Wrocławskie ---> Mietków
# Dates:		2026-07-07 - 2026-07-07
# Times:		06:33:00 - 06:39:00
#
# Line:		D6
# Stops:		Mietków ---> Imbramowice
# Dates:		2026-07-07 - 2026-07-07
# Times:		06:39:00 - 06:43:00
#
# Line:		D6
# Stops:		Imbramowice ---> Żarów
# Dates:		2026-07-07 - 2026-07-07
# Times:		06:44:00 - 06:49:00
#
# Line:		D6
# Stops:		Żarów ---> Jaworzyna Śląska
# Dates:		2026-07-07 - 2026-07-07
# Times:		06:49:00 - 06:54:00
#
# Line:		D6
# Stops:		Jaworzyna Śląska ---> Świebodzice
# Dates:		2026-07-07 - 2026-07-07
# Times:		06:58:00 - 07:06:00
#
# Line:		D6
# Stops:		Świebodzice ---> Wałbrzych Szczawienko
# Dates:		2026-07-07 - 2026-07-07
# Times:		07:07:00 - 07:16:00
#
# Line:		D6
# Stops:		Wałbrzych Szczawienko ---> Wałbrzych Miasto
# Dates:		2026-07-07 - 2026-07-07
# Times:		07:17:00 - 07:21:00
#
# Line:		D6
# Stops:		Wałbrzych Miasto ---> Wałbrzych Centrum
# Dates:		2026-07-07 - 2026-07-07
# Times:		07:22:00 - 07:24:00
#
# Line:		D6
# Stops:		Wałbrzych Centrum ---> Wałbrzych Fabryczny
# Dates:		2026-07-07 - 2026-07-07
# Times:		07:25:00 - 07:29:00
#
# Line:		D6
# Stops:		Wałbrzych Fabryczny ---> Wałbrzych Główny
# Dates:		2026-07-07 - 2026-07-07
# Times:		07:29:00 - 07:34:00
