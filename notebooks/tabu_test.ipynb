# %%
from pathlib import Path
import sys
import random

import pandas as pd

project_root = Path.cwd()
if not (project_root / "src").exists():
    project_root = project_root.parent

if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

from src.tabu_a import *
from src.graph import *
from src.utils import print_paths

# %%
test_time = pd.Timestamp("2026-10-09 11:00:00")
# graph = Graph(test_time, with_locations=True)
# restult = evaluate_solution_arr_time([1413424, 1413136, 1413137, 1413138, 1413139, 1413140, 1413141, 1413142, 1413144, 1413424, 1413136, 1413137, 1413138, 1413139, 1413140, 1413141, 1413142, 1413144, 1413424, 1413136, 1413137, 1413138, 1413139, 1413140, 1413141, 1413142, 1413144, 1413424, 1413136, 1413137, 1413138, 1413139, 1413140, 1413141, 1413142, 1413144, 1413424, 1413136, 1413137, 1413138, 1413139, 1413140, 1413141, 1413142, 1413144, 1413424, 1413136], graph, test_time, should_log=True)

# print(str(restult))

# %%
test_time = pd.Timestamp("2026-12-11 11:00:00")
# graph = Graph(test_time, with_locations=True)
# restult2 = evaluate_solution_arr_time([1413424, 1413136, 1413137, 1413138, 1413139, 1413140, 1413141, 1413142, 1413144, 1413424, 1413136, 1413137, 1413138, 1413139, 1413140, 1413141, 1413142, 1413144, 1413424, 1413136, 1413137, 1413138, 1413139, 1413140, 1413141, 1413142], graph, test_time, should_log=True)

# print(str(restult2))

# %%
test_time = pd.Timestamp("2026-07-03 11:00:00")
result = tabu_a(1413137, [1413139, 1413137, 1413136, 1413138 , 1413424], 't', pd.Timestamp("2026-12-11 11:00:00"))
# print_paths(result, should_print_path=True)
print_paths(result)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 2
#       1 test_time = pd.Timestamp("2026-07-03 11:00:00")
# ----> 2 result = tabu_a(1413137, [1413139, 1413137, 1413136, 1413138 , 1413424], 't', pd.Timestamp("2026-12-11 11:00:00"))
#       3 # print_paths(result, should_print_path=True)
#       4 print_paths(result)
#
# File s:\Studia\6sem\AI\Laby\1\src\tabu_a.py:152, in tabu_a(start, stops, mode, time, names_passed)
#     149     return None, None
#     151 best_solution = stops[:]
# --> 152 best_score = evaluate_solution_arr_time(best_solution, graph, time, should_log=False, names_passed=names_passed)
#     154 if(best_score > pd.Timestamp("2026-12-13")):
#     155     print(best_score)
#
# File s:\Studia\6sem\AI\Laby\1\src\tabu_a.py:40, in evaluate_solution_arr_time(solution, graph, time, should_log, names_passed)
#      37 if not result or not result[1]:
#      38     return pd.Timestamp("2300-12-12")
# ---> 40 date, path = result
#      41 last_arr_time = path[-1]['arr_time']
#      43 if should_log:
#
# ValueError: too many values to unpack (expected 2)

# %%
result = tabu_a(
    'Głogów Huta', 
    ['Głogów Huta', 'Głuszyca', 'Głogów Wróblin', 'Głogów', 'Żary'], 
    't', 
    pd.Timestamp("2026-12-11 11:00:00"), 
    names_passed=True)
print_paths(result)
# Out:
# 1 --> Best score: 2026-12-12 06:21:00
# Fastest arrival: 2026-12-12 06:21:00
#
# Best city order:
# 	1. Głogów Huta
# 	2. Głuszyca
# 	3. Żary
# 	4. Głogów
# 	5. Głogów Wróblin
# 	6. Głogów Huta

# %%
cities = [
    'Żary', 'Wrocław Główny', 'Bardo Śląskie', 'Żagań', 'Brzeg Dolny',
    'Legnica','Jaworzyna Śląska','Świdnica Miasto','Wałbrzych Miasto','Wałbrzych Główny',
    'Jelenia Góra', 'Szklarska Poręba Górna','Gryfów Śląski','Lubań Śląski','Zgorzelec',
    'Bolesławiec','Lubin', 'Głogów','Wołów',  'Środa Śląska',
    'Kłodzko Główne', 'Polanica-Zdrój',  'Duszniki-Zdrój',  'Kudowa-Zdrój', 'Ząbkowice Śląskie'
]

random.shuffle(cities)

print(cities)

result = tabu_a(
    'Wrocław Główny', 
    cities,
    't', 
    pd.Timestamp("2026-05-11 11:00:00"), 
    names_passed=True)
print_paths(result)
# Out:
# ['Lubań Śląski', 'Wałbrzych Miasto', 'Gryfów Śląski', 'Kudowa-Zdrój', 'Wrocław Główny', 'Polanica-Zdrój', 'Ząbkowice Śląskie', 'Żary', 'Lubin', 'Świdnica Miasto', 'Jelenia Góra', 'Głogów', 'Środa Śląska', 'Wołów', 'Brzeg Dolny', 'Kłodzko Główne', 'Szklarska Poręba Górna', 'Bolesławiec', 'Legnica', 'Jaworzyna Śląska', 'Zgorzelec', 'Duszniki-Zdrój', 'Bardo Śląskie', 'Wałbrzych Główny', 'Żagań']
# 1 --> Best score: 2026-05-14 22:04:00
# 1 --> Best score: 2026-05-14 13:53:00
# 1 --> Best score: 2026-05-14 09:43:00
# 5 --> Best score: 2026-05-14 07:48:00
# 1 --> Best score: 2026-05-14 07:09:00
# 1 --> Best score: 2026-05-14 05:20:00
# 1 --> Best score: 2026-05-13 23:31:00
# 2 --> Best score: 2026-05-13 22:04:00
# 1 --> Best score: 2026-05-13 20:44:00
# 1 --> Best score: 2026-05-13 17:13:00
# Fastest arrival: 2026-05-13 17:13:00
#
# Best city order:
# 	1. Wrocław Główny
# 	2. Wałbrzych Miasto
# 	3. Głogów
# 	4. Środa Śląska
# 	5. Wołów
# 	6. Brzeg Dolny
# 	7. Kłodzko Główne
# 	8. Szklarska Poręba Górna
# 	9. Kudowa-Zdrój
# 	10. Duszniki-Zdrój
# 	11. Bardo Śląskie
# 	12. Wałbrzych Główny
# 	13. Ząbkowice Śląskie
# 	14. Polanica-Zdrój
# 	15. Lubin
# 	16. Żary
# 	17. Żagań
# 	18. Legnica
# 	19. Bolesławiec
# 	20. Zgorzelec
# 	21. Lubań Śląski
# 	22. Gryfów Śląski
# 	23. Jelenia Góra
# 	24. Jaworzyna Śląska
# 	25. Świdnica Miasto
# 	26. Wrocław Główny
