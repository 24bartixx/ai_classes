# %%
from pathlib import Path
import sys
import random

import pandas as pd

project_root = Path.cwd()
if not (project_root / "src").exists():
    project_root = project_root.parent

if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

from src.tabu_a import *
from src.graph import *
from src.utils import print_paths

# %%
test_time = pd.Timestamp("2026-10-09 11:00:00")
# graph = Graph(test_time, with_locations=True)
# restult = evaluate_solution_arr_time([1413424, 1413136, 1413137, 1413138, 1413139, 1413140, 1413141, 1413142, 1413144, 1413424, 1413136, 1413137, 1413138, 1413139, 1413140, 1413141, 1413142, 1413144, 1413424, 1413136, 1413137, 1413138, 1413139, 1413140, 1413141, 1413142, 1413144, 1413424, 1413136, 1413137, 1413138, 1413139, 1413140, 1413141, 1413142, 1413144, 1413424, 1413136, 1413137, 1413138, 1413139, 1413140, 1413141, 1413142, 1413144, 1413424, 1413136], graph, test_time, should_log=True)

# print(str(restult))

# %%
test_time = pd.Timestamp("2026-12-11 11:00:00")
# graph = Graph(test_time, with_locations=True)
# restult2 = evaluate_solution_arr_time([1413424, 1413136, 1413137, 1413138, 1413139, 1413140, 1413141, 1413142, 1413144, 1413424, 1413136, 1413137, 1413138, 1413139, 1413140, 1413141, 1413142, 1413144, 1413424, 1413136, 1413137, 1413138, 1413139, 1413140, 1413141, 1413142], graph, test_time, should_log=True)

# print(str(restult2))

# %%
test_time = pd.Timestamp("2026-07-03 11:00:00")
result = tabu_a(1413137, [1413139, 1413137, 1413136, 1413138 , 1413424], 't', pd.Timestamp("2026-12-11 11:00:00"))
# print_paths(result, should_print_path=True)
print_paths(result)
# Out:
# Fastest arrival: 2026-12-12 06:21:00
#
# Best city order:
# 	1. 1413137
# 	2. 1413139
# 	3. 1413424
# 	4. 1413136
# 	5. 1413138
# 	6. 1413137
# Execution time:		0.249038 seconds
# Minimized value:	2026-12-12 06:21:00 seconds

# %%
result = tabu_a(
    'Głogów Huta', 
    ['Głogów Huta', 'Głuszyca', 'Głogów Wróblin', 'Głogów', 'Żary'], 
    't', 
    pd.Timestamp("2026-12-11 11:00:00"), 
    names_passed=True)
print_paths(result)
# Out:
# Fastest arrival: 2026-12-12 06:21:00
#
# Best city order:
# 	1. Głogów Huta
# 	2. Głuszyca
# 	3. Żary
# 	4. Głogów
# 	5. Głogów Wróblin
# 	6. Głogów Huta
# Execution time:		0.233815 seconds
# Minimized value:	2026-12-12 06:21:00 seconds

# %%
cities = [
    'Żary', 'Wrocław Główny', 'Bardo Śląskie', 'Żagań', 'Brzeg Dolny',
    'Legnica','Jaworzyna Śląska','Świdnica Miasto','Wałbrzych Miasto','Wałbrzych Główny',
    'Jelenia Góra', 'Szklarska Poręba Górna','Gryfów Śląski','Lubań Śląski','Zgorzelec',
    'Bolesławiec','Lubin', 'Głogów','Wołów',  'Środa Śląska',
    'Kłodzko Główne', 'Polanica-Zdrój',  'Duszniki-Zdrój',  'Kudowa-Zdrój', 'Ząbkowice Śląskie'
]

random.shuffle(cities)

print("CITIES:")
for i, city in enumerate(cities):
    print(f"\t{i}: {city}")

result = tabu_a(
    'Wrocław Główny', 
    cities,
    't', 
    pd.Timestamp("2026-05-11 11:00:00"), 
    names_passed=True,
    should_log=True
)

print_paths(result)
# Out:
# CITIES:
# 	0: Wrocław Główny
# 	1: Wołów
# 	2: Żary
# 	3: Głogów
# 	4: Polanica-Zdrój
# 	5: Wałbrzych Główny
# 	6: Duszniki-Zdrój
# 	7: Środa Śląska
# 	8: Brzeg Dolny
# 	9: Wałbrzych Miasto
# 	10: Ząbkowice Śląskie
# 	11: Bolesławiec
# 	12: Legnica
# 	13: Zgorzelec
# 	14: Żagań
# 	15: Lubin
# 	16: Jelenia Góra
# 	17: Gryfów Śląski
# 	18: Bardo Śląskie
# 	19: Lubań Śląski
# 	20: Kłodzko Główne
# 	21: Świdnica Miasto
# 	22: Jaworzyna Śląska
# 	23: Kudowa-Zdrój
# 	24: Szklarska Poręba Górna
#
# TRACKING PROGRESS:
# 	Best score: 2026-05-15 09:39:00
# 	Best score: 2026-05-14 22:04:00
# 	Best score: 2026-05-14 20:44:00
# 	Best score: 2026-05-14 16:27:00
# 	Best score: 2026-05-14 09:43:00
# 	Best score: 2026-05-14 07:33:00
# 	Best score: 2026-05-13 20:44:00
# 	Best score: 2026-05-13 20:19:00
# 	Best score: 2026-05-13 17:54:00
#
# Fastest arrival: 2026-05-13 17:54:00
#
# Best city order:
# 	1. Wrocław Główny
# 	2. Wołów
# 	3. Żary
# 	4. Legnica
# 	5. Bardo Śląskie
# 	6. Kłodzko Główne
# 	7. Polanica-Zdrój
# 	8. Duszniki-Zdrój
# 	9. Kudowa-Zdrój
# 	10. Jaworzyna Śląska
# 	11. Świdnica Miasto
# 	12. Wałbrzych Główny
# 	13. Szklarska Poręba Górna
# 	14. Bolesławiec
# 	15. Ząbkowice Śląskie
# 	16. Wałbrzych Miasto
# 	17. Jelenia Góra
# 	18. Gryfów Śląski
# 	19. Lubań Śląski
# 	20. Zgorzelec
# 	21. Żagań
# 	22. Lubin
# 	23. Środa Śląska
# 	24. Brzeg Dolny
# 	25. Głogów
# 	26. Wrocław Główny
# Execution time:		26.907089 seconds
# Minimized value:	2026-05-13 17:54:00 seconds
